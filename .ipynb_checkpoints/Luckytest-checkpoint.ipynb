# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\DELL\\miniconda3\\envs\\min_ds-env\\python.exe'

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import time
import json
import re
import pandas as pd # Dùng để đọc và hiển thị file csv/tsv
from datetime import datetime, timedelta # Dùng để xử lý dữ liệu thời gian
import os
import urllib.robotparser # Kiểm tra file robot.txt có được phép crawl không
from selenium import webdriver

# %%
#PATH = 'C:\Program Files (x86)\chromedriver.exe'

def GetUsers():
    Users = []
    
    url = 'https://soundcloud.com/discover/sets/charts-top:all-music:vn'
    #url = 'https://soundcloud.com/discover/sets/charts-top:hiphoprap:vn'
    main_url = 'https://soundcloud.com'
    
    browser_1 = webdriver.Chrome(executable_path="chromedriver.exe")
    browser_1.get(url)
    time.sleep(1)
    
    # To make it load more scroll to the bottom of the page (repeat if you want to)
    
    lenOfPage_1 = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    match_1 = False
    while(match == False):
        lastCount = lenOfPage
        time.sleep(1)
        lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
        if lastCount == lenOfPage:
                match = True
                    
    html_source = browser.page_source
    browser.quit()
    soup = BeautifulSoup(html_source, 'html.parser')
    for id in soup.findAll('a', {'class' : 'trackItem__username sc-link-light sc-link-secondary'}):
        UsersTemp = []
        
        UsersTemp.append(url)
        UsersTemp.append(id.get('href')) #lay link de di den tracks va playlist cua moi user
        UsersTemp.append(id.text) #lay username
        
        browser = webdriver.Chrome(executable_path="chromedriver.exe")
        browser.get(url)
        time.sleep(1)
    
    # To make it load more scroll to the bottom of the page (repeat if you want to)
    
        lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
        match = False
        while(match == False):
            lastCount = lenOfPage
            time.sleep(1)
            lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
            if lastCount == lenOfPage:
                    match = True

        html_source = browser.page_source
        browser.quit()
        
        Users.append(UsersTemp)
        
    return Users

def GetTracks(Users):
    TracksOfAllUsers = []
    
    for i in range(len(Users)):
        TrackOfOneUser = []
        
        url = 'https://soundcloud.com'
        url = url + str(Users[i][1]) + '/tracks'
    
        browser = webdriver.Chrome(executable_path="chromedriver.exe")
        browser.get(url)
        time.sleep(3)

        # To make it load more scroll to the bottom of the page (repeat if you want to)
        
        lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
        match = False
        while(match == False):
            lastCount = lenOfPage
            time.sleep(3)
            lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
            if lastCount == lenOfPage:
                match = True
                
        html_source = browser.page_source
        browser.quit()
        
        soup = BeautifulSoup(html_source, 'html.parser')
        check = soup.findAll('a', {'class' : 'sc-link-primary soundTitle__title sc-link-dark sc-text-h4'})
        if check == []:
            TrackOfOneUser.append(Users[i][2])
            TrackOfOneUser.append('None')
            TracksOfAllUsers.append(TrackOfOneUser)
            print('OK')
        else:
            for id in check:
                TrackOfOneUser = []
                TrackOfOneUser.append(Users[i][2])
                TrackOfOneUser.append(id.text) #lay track cua 1 user
                TracksOfAllUsers.append(TrackOfOneUser)
    return TracksOfAllUsers

def GetPlaylist(Users):
    PlaylistOfAllUsers = []
    
    for i in range(len(Users)):
        InfoOfOnePlaylist = []
        
        url = 'https://soundcloud.com'
        url = url + str(Users[i][1]) + '/sets' #lay duong dan den playlist
        
        browser = webdriver.Chrome(executable_path="chromedriver.exe")
        browser.get(url)
        time.sleep(3)

        # To make it load more scroll to the bottom of the page (repeat if you want to)
        
        lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
        match = False
        while(match == False):
            lastCount = lenOfPage
            time.sleep(3)
            lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
            if lastCount == lenOfPage:
                match = True
                
        html_source = browser.page_source
        browser.quit()
        
        soup = BeautifulSoup(html_source, 'html.parser')
        check = soup.findAll('div', {'class' : 'sound__content'})
        if check == []:
            InfoOfOnePlaylist.append(Users[i][2])
            InfoOfOnePlaylist.append('None')
            InfoOfOnePlaylist.append('None')
            PlaylistOfAllUsers.append(InfoOfOnePlaylist)
        else:        
            for id in check:
                Title = id.find('a', {'class' : 'sc-link-primary soundTitle__title sc-link-dark sc-text-h4'})
                Tracks = id.findAll('span', {'class' : 'compactTrackListItem__trackTitle sc-text-primary sc-text-h4'})
                for Track in Tracks:
                    InfoOfOnePlaylist = []
                    InfoOfOnePlaylist.append(Users[i][2])
                    InfoOfOnePlaylist.append(Title.text)
                    InfoOfOnePlaylist.append(Track.text)
                    PlaylistOfAllUsers.append(InfoOfOnePlaylist)
    return PlaylistOfAllUsers

def writeUsersToCsv(List2D, filename):
    df = pd.DataFrame(List2D, columns = ['Url', 'Users Link', 'User Name'])
    df.to_csv(filename, index = True, sep = '\t')
    
def writeTracksToCsv(List2D, filename):
    df = pd.DataFrame(List2D, columns = ['User Name', 'Tracks Of One User'])
    df.to_csv(filename, index = True, sep = '\t')

def writePlaylistsToCsv(List2D, filename):
    df = pd.DataFrame(List2D, columns = ['User Name', 'Playlists Of One User', 'Tracks Of One Playlist'])
    df.to_csv(filename, index = True, sep = '\t')

# %%
Users = GetUsers()
#print(Users[0])
Tracks = GetTracks(Users)
#Playlists = GetPlaylist(Users)
#print(Tracks)
#writeUsersToCsv(Users, './Crawl_data/users.csv')
#writeTracksToCsv(Tracks, './Crawl_data/tracks.csv')
#writePlaylistsToCsv(Playlists, './Crawl_data/playlists.csv')
#print(len(Users[0]))
#print(len(Users[1]))
#print(len(Users[2]))
#GetTracks(Users)
#print(len(GetPlaylist(Users)))
# Out:
# OK
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_41784/828729862.py in <module>
#       1 Users = GetUsers()
#       2 #print(Users[0])
# ----> 3 Tracks = GetTracks(Users)
#       4 #Playlists = GetPlaylist(Users)
#       5 #print(Tracks)
#
# ~\AppData\Local\Temp/ipykernel_41784/2721569039.py in GetTracks(Users)
#      51         # To make it load more scroll to the bottom of the page (repeat if you want to)
#      52
# ---> 53         lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
#      54         match = False
#      55         while(match == False):
#
# ~\miniconda3\envs\min_ds-env\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     632             command = Command.EXECUTE_SCRIPT
#     633
# --> 634         return self.execute(command, {
#     635             'script': script,
#     636             'args': converted_args})['value']
#
# ~\miniconda3\envs\min_ds-env\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\miniconda3\envs\min_ds-env\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=95.0.4638.69)

# %%
def TestGetTracks(Users):
    TracksOfAllUsers = []
    
    url = 'https://soundcloud.com/winnodamidside'
    browser = webdriver.Chrome(executable_path="chromedriver.exe")
    browser.get(url)
    time.sleep(3)

    # To make it load more scroll to the bottom of the page (repeat if you want to)
    
    lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    match = False
    while(match == False):
        lastCount = lenOfPage
        time.sleep(3)
        lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
        if lastCount == lenOfPage:
            match = True
            
    html_source = browser.page_source
    browser.quit()

    soup = BeautifulSoup(html_source, 'html.parser')
    TrackOfOneUser = []
    check = soup.findAll('a', {'class' : 'sc-link-primary soundTitle__title sc-link-dark sc-text-h4'})
    if check == []:
        TrackOfOneUser.append(Users[0][2])
        TrackOfOneUser.append('None')
        TracksOfAllUsers.append(TrackOfOneUser)
    else:
        for id in check:
            TrackOfOneUser = []
            TrackOfOneUser.append(Users[0][2])
            TrackOfOneUser.append(id.text)
            TracksOfAllUsers.append(TrackOfOneUser)
    return TracksOfAllUsers

def TestGetPlaylist(Users):
    url = 'https://soundcloud.com/nguy-n-to-n-401524044/sets'
    
    browser = webdriver.Chrome(executable_path="chromedriver.exe")
    browser.get(url)
    time.sleep(3)

    # To make it load more scroll to the bottom of the page (repeat if you want to)
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)
    html_source = browser.page_source
    browser.quit()
        
    soup = BeautifulSoup(html_source, 'html.parser')
    for id in soup.findAll('div', {'class' : 'sound__content'}):
        Title = id.find('a', {'class' : 'sc-link-primary soundTitle__title sc-link-dark sc-text-h4'})
        print(Title.text)
        Tracks = id.findAll('span', {'class' : 'compactTrackListItem__trackTitle sc-text-primary sc-text-h4'})
        for Track in Tracks:
            print(Track.text)
        print('\n')

# %%
tr = TestGetTracks(Users)
writeTracksToCsv(tr, './Crawl_data/tracks.csv')
#TestGetPlaylist(Users)
            TracksOfAllUsers[0] += UserName
            TracksOfAllUsers[1] += TrackName
            TracksOfAllUsers[2] += TrackName
            TracksOfAllUsers[3] += TrackName
            TracksOfAllUsers[4] += TrackName

# %%
def TestGetUserV2():    
    url = 'https://soundcloud.com/discover/sets/charts-top:all-music:vn'
    
    # tạo users rỗng và thềm cái list rỗng để chứa username,userlink
    Users = []
    Users.append([])
    Users.append([])
    Users.append([])
    
    main_url = 'https://soundcloud.com'
    
    UsersLink = []
    UsersName = []
        
    chrome_options = webdriver.ChromeOptions()
    prefs = {
        "profile.managed_default_content_settings.images": 2
    }
    chrome_options.add_experimental_option("prefs", prefs)
    
    browser = webdriver.Chrome(executable_path="chromedriver.exe", options=chrome_options)
    browser.get(url)
    time.sleep(1)

    # To make it load more scroll to the bottom of the page (repeat if you want to)

    lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    match = False
    while(match == False):
        lastCount = lenOfPage
        time.sleep(1)
        lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
        if lastCount == lenOfPage:
                    match = True

    html_source = browser.page_source
    browser.quit()
    soup = BeautifulSoup(html_source, 'html.parser')
    for id in soup.findAll('a', {'class' : 'trackItem__username sc-link-light sc-link-secondary'}):
        UsersLink.append(main_url + str(id.get('href')))
        UsersName.append(id.text)
        
    #đoạn này nối chuỗi mới vào Users[0], Users[1] 
    Users[0] += UsersLink
    Users[1] += UsersName
    return Users

def TestGetTracksV2(Users):
    TracksOfAllUsers = []
    TracksOfAllUsers.append([]) #tên mỗi user
    TracksOfAllUsers.append([]) #tên mỗi track của user
    TracksOfAllUsers.append([]) #lấy thời gian post
    TracksOfAllUsers.append([]) #lấy lượt nghe
    TracksOfAllUsers.append([]) #lấy lượt thich
    
    for i in range(len(Users[0])):
        UserName = []
        TrackName = []
        PostTime = []
        Plays = []
        Likes = []
        #----------------------------
        url = str(Users[0][i]) + '/tracks'
        
        chrome_options = webdriver.ChromeOptions()
        prefs = {
            "profile.managed_default_content_settings.images": 2
        }
        chrome_options.add_experimental_option("prefs", prefs)
        
        browser = webdriver.Chrome(executable_path="chromedriver.exe", options=chrome_options)
        browser.get(url)
        time.sleep(1)

        # To make it load more scroll to the bottom of the page (repeat if you want to)
        
        lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
        match = False
        while(match == False):
            lastCount = lenOfPage
            time.sleep(1)
            lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
            if lastCount == lenOfPage:
                match = True
                
        html_source = browser.page_source
        browser.quit()
        
        soup = BeautifulSoup(html_source, 'html.parser')
        check = soup.findAll('div', {'class' : 'sound__content'})
        if check == []:
            UserName.append(Users[1][i])
            TrackName.append('None')
            PostTime.append('None')
            Plays.append('None')
            Likes.append('None')
            
            TracksOfAllUsers[0] += UserName
            TracksOfAllUsers[1] += TrackName
            TracksOfAllUsers[2] += PostTime
            TracksOfAllUsers[3] += Plays
            TracksOfAllUsers[4] += Likes
        else:
            for id in check:
                UserName = []
                TrackName = []
                PostTime = []
                Plays = []
                Likes = []
        
                UserName.append(Users[1][i])
            
                trackname = id.find('a', {'class' : 'sc-link-primary soundTitle__title sc-link-dark sc-text-h4'})
                Like = id.find('button', {'class' : 'sc-button-like sc-button-secondary sc-button sc-button-small sc-button-responsive'})
                info = id.findAll('span', {'class' : 'sc-visuallyhidden'})
                print(Users[1][i])
                print(trackname.text)
                print(len(info))
                print('\n')
                
                TrackName.append(trackname.text.replace('\n', ''))
                PostTime.append(info[0].text.replace('\n', '')) #lay thoi gian post
                
                if len(info) < 2:
                    Plays.append('0')
                    Likes.append('0')
                else:
                    Plays.append(info[1].text.replace('\n', '')) #lay luot xem
                    Likes.append(Like.text.replace('\n', ''))
                TracksOfAllUsers[0] += UserName
                TracksOfAllUsers[1] += TrackName
                TracksOfAllUsers[2] += PostTime
                TracksOfAllUsers[3] += Plays
                TracksOfAllUsers[4] += Likes
    return TracksOfAllUsers

def TestwriteTracksToCsv(List5D, filename):
    df = pd.DataFrame({
        'User Name': pd.Series(user for user in List5D[0]),
        'Track Name': pd.Series(track for track in List5D[1]),
        'Post Time' : pd.Series(t for t in List5D[2]),
        'Plays' : pd.Series(p for p in List5D[3]),
        'Likes' : pd.Series(L for L in List5D[4]),
    })
    df.to_csv(filename, index = False)

# %%
User_top = TestGetUserV2()
Tr = TestGetTracksV2(User_top)
TestwriteTracksToCsv(Tr, './Crawl_data/tracks.csv')
Tracks = pd.read_csv('./Crawl_data/tracks.csv')
Tracks
# Out:
# Hustlang Winno 🐉🐍
#
# Tell Ur Mom II - Winno (ft Heily)
#
# 3
#
#
# Hustlang Winno 🐉🐍
#
# Lil Thang - pu ekvw Ft Hashone
#
# 3
#
#
# Hustlang Winno 🐉🐍
#
# Bốp 2 - Winno (Godthic dissin)
#
# 3
#
#
# Hustlang Winno 🐉🐍
#
# Bốp - Winno (Reply Zuyngusi)
#
# 3
#
#
# Hustlang Winno 🐉🐍
#
# Bounce. (remixbyMoTienSinh)
#
# 3
#
#
# Hustlang Winno 🐉🐍
#
# Bounce. (remixbyPinkyMolly777)
#
# 3
#
#
# Hustlang Winno 🐉🐍
#
# DEMØ ₩ł₦₦Ø
#
# 3
#
#
# Hustlang Winno 🐉🐍
#
# Bounce - Winno (#PoppinChallenge)
#
# 3
#
#
# Hustlang Winno 🐉🐍
#
# Bê Cálm Đòwn - DanhHuy x Riet x Winno
#
# 3
#
#
# Hustlang Winno 🐉🐍
#
# Diss sml Sinike
#
# 3
#
#
# Hustlang Winno 🐉🐍
#
# Hai Tám Bốn - Winno
#
# 3
#
#
# Hustlang Winno 🐉🐍
#
# demo thoi khong co gi het
#
# 3
#
#
# Hustlang Winno 🐉🐍
#
# Mùa Xuân Cuối Cùng - Riet x Winno x Joe
#
# 3
#
#
# Hustlang Winno 🐉🐍
#
# [PP x Madsound] Perfect Sound - Winno x Obito
#
# 3
#
#
# Hustlang Winno 🐉🐍
#
# Em vui đi - Winno
#
# 3
#
#
# Hustlang Winno 🐉🐍
#
# YunMidside - Winno x WarC (Prod Lu)
#
# 3
#
#
# Hustlang Winno 🐉🐍
#
# Demo Winno 1
#
# 3
#
#
# THINHHO
#
# PHI HÀNH GIA - RENJA x SLOW T x LIL WUYN x KAIN x SUGAR CANE
#
# 3
#
#
# YC
#
# Big City Noise Test - Rhymastic
#
# 3
#
#
# YC
#
# Nụ Cười - Rhymastic
#
# 3
#
#
# YC
#
# Can Gi Hon Remix
#
# 3
#
#
# YC
#
# Mặt Trời Của Em - Phương Ly feat. JustaTee (Rhymastic's 1900 Remix)
#
# 3
#
#
# YC
#
# Treasure Vocal 90bpm
#
# 3
#
#
# YC
#
# Treasure Instrumental 90bpm
#
# 3
#
#
# YC
#
# Wet Lens Remix
#
# 3
#
#
# YC
#
# Ech Bao Dissin - Young Crizzal
#
# 3
#
#
# YC
#
# Bray Dissin
#
# 3
#
#
# YC
#
# Ngược Đời - Rhymastic
#
# 3
#
#
# YC
#
# Bản Kiểm Điểm - Rhymastic
#
# 3
#
#
# YC
#
# Hanh Trinh Cua Giot Nang
#
# 3
#
#
# YC
#
# Ve Khoi (Bass House Remix)
#
# 3
#
#
# YC
#
# Paranoid (Original Mix) [Demo Preview]
#
# 3
#
#
# YC
#
# Vut Tan (Gala)
#
# 3
#
#
# YC
#
# Vui Di Em (Chung Ket)
#
# 3
#
#
# YC
#
# Sorry (Vong 8)
#
# 3
#
#
# YC
#
# Tim Lai Reu Phong (Vong 7)
#
# 3
#
#
# YC
#
# Ai Kho Vi Ai (Vong 6)
#
# 3
#
#
# YC
#
# Ve Khoi (Vong 5)
#
# 3
#
#
# YC
#
# Chi Toi (Vong 4)
#
# 3
#
#
# YC
#
# Chuyen Chang Co Don (Vong 2)
#
# 3
#
#
# YC
#
# Day Dream (Vong 1)
#
# 3
#
#
# YC
#
# Nguoi Va Ta (Instrumental)
#
# 3
#
#
# YC
#
# Người và Ta (feat. Thanh Huyền)
#
# 3
#
#
# YC
#
# Valentine - Miko Lan Trinh (Rhymastic Edit)
#
# 3
#
#
# YC
#
# Happy Birthday Song
#
# 3
#
#
# YC
#
# Old School - Rhymastic
#
# 3
#
#
# YC
#
# Xilevolau (Melodic Deep House Remix)
#
# 3
#
#
# YC
#
# Sau Trong Em (Disco Remix)
#
# 3
#
#
# YC
#
# Ban Khoan feat. Duong Tran Nghia (Rhymastic Trap Remix)
#
# 3
#
#
# YC
#
# Do You Remember - Duong Tran Nghia feat. Mr.A (Rhymastic Remix)
#
# 3
#
#
# YC
#
# Cho Em Mot Ngay (Hard Dance Remix) [Tuyet Dinh Tranh Tai Drop Release]
#
# 3
#
#
# YC
#
# Say You Do - Tiên Tiên (Future Funk Remix) [Preview]
#
# 3
#
#
# YC
#
# DeepCME
#
# 3
#
#
# YC
#
# Valentine ft. Miko Lan Trinh (Deep House Remix)
#
# 3
#
#
# YC
#
# Deep Against The World (Rhymastic's Extended Mix)
#
# 3
#
#
# YC
#
# Rieng Minh Ta (Original Mix)
#
# 3
#
#
# YC
#
# Yeu 4
#
# 3
#
#
# YC
#
# Băn Khoăn (feat. Dương Trần Nghĩa)
#
# 3
#
#
# YC
#
# Sad Flow
#
# 3
#
#
# YC
#
# Yeu 3 (Acapella)
#
# 3
#
#
# YC
#
# Yêu part 1
#
# 3
#
#
# YC
#
# Two Against The World - Lil Knight (Rhymastic's House Remix)
#
# 3
#
#
# YC
#
# I Will Be Fine - Yanbi feat. Rhymastic
#
# 3
#
#
# YC
#
# Tìm (Original Mix)
#
# 3
#
#
# YC
#
# Lạc - Rhymastic
#
# 3
#
#
# YC
#
# Diss G Fam
#
# 3
#
#
# YC
#
# Diss Acy Final
#
# 3
#
#
# YC
#
# Diss Acy 2
#
# 3
#
#
# YC
#
# Diss Acy
#
# 3
#
#
# YC
#
# Diss ngu si
#
# 3
#
#
# YC
#
# ATOG
#
# 3
#
#
# YC
#
# Khi tao ra tay 2 - Rhymastic feat. Da Vickie & Silver C
#
# 3
#
#
# YC
#
# Homie - Rhymastic
#
# 3
#
#
# YC
#
# Can - Rhymastic feat. Soobin
#
# 3
#
#
# YC
#
# Amarant Vinahouse Remix - Com feat. Danny & CK Babe
#
# 3
#
#
# YC
#
# Loi yeu thuong - Com feat. Cuong Ngo & Danny
#
# 3
#
#
# YC
#
# Neu may la rapper (full version)
#
# 3
#
#
# YC
#
# Đam Mê - Rhymastic
#
# 3
#
#
# Hieu Tran Music Producer
#
# Tình Nguyện Viên - Lê Minh MTV
#
# 3
#
#
# Hieu Tran Music Producer
#
# Trốn Tìm - Đen ft. MTV band ( Hiếu Trần Lofi Remix)
#
# 3
#
#
# Hieu Tran Music Producer
#
# Muộn rồi mà sao còn - Sơn Tùng M-TP ( Hiếu Trần Lofi Remix)
#
# 3
#
#
# Hieu Tran Music Producer
#
# Thật Tâm Em Rất Yêu Anh - Đào Bá Lộc
#
# 3
#
#
# Hieu Tran Music Producer
#
# Liên Quân Mobile - Khi bạn mê game nhưng cuộc đời đưa đẩy bạn làm Music Producer - Hiếu Trần
#
# 2
#
#
# Hieu Tran Music Producer
#
# Coffin Dance ( Astromonia) in 8 Different Genres/Styles - Hiếu Trần
#
# 3
#
#
# Hieu Tran Music Producer
#
# Tại sao - Thiên Vương
#
# 2
#
#
# Hieu Tran Music Producer
#
# Tân dòng sông ly biệt OST - Tình Sâu Đậm Mưa Nhạt Nhoà ( Lofi Mix) - Tiểu Đình - 情深深雨濛濛
#
# 3
#
#
# Hieu Tran Music Producer
#
# Khúc hát đôi bàn tay - (ST. Nhạc Sỹ Phạm Tuyên) - Hiếu Trần ( Karaoke thiếu nhi)
#
# 2
#
#
# Hieu Tran Music Producer
#
# Khúc hát đôi bàn tay - (ST. Nhạc Sỹ Phạm Tuyên) - Hiếu Trần ( Beat chuẩn)
#
# 3
#
#
# Hieu Tran Music Producer
#
# Khúc hát đôi bàn tay - (ST. Nhạc Sỹ Phạm Tuyên) - Hiếu Trần
#
# 2
#
#
# Hieu Tran Music Producer
#
# BoneyM Meets Bruno Mars - Phương Vy Ft. Hiếu Trần
#
# 2
#
#
# Hieu Tran Music Producer
#
# Corona Virus Song ( Covid-19)
#
# 3
#
#
# Hieu Tran Music Producer
#
# Chuyện nhỏ Remix 2019 - MTV Band
#
# 2
#
#
# Hieu Tran Music Producer
#
# Hoa sứ nhà nàng - Phương Vy Idol & Sean Trace
#
# 3
#
#
# Hieu Tran Music Producer
#
# Nhạt phai Remix 2019 - MTV ( Chill Phết Version)
#
# 2
#
#
# Hieu Tran Music Producer
#
# Untitled - Original No.1 - Vanny Pham
#
# 2
#
#
# Hieu Tran Music Producer
#
# Oh Baby Baby - Phương Vy Idol & Sean Trace
#
# 2
#
#
# Hieu Tran Music Producer
#
# Hãy Trao Cho Anh - Sơn Tùng M-TP Ft. Snoop Dogg ( Hieu Tran Chill Lofi Remix)
#
# 3
#
#
# Hieu Tran Music Producer
#
# Thật Lòng - Đào Bá Lộc
#
# 3
#
#
# Hieu Tran Music Producer
#
# Saigon đẹp lắm - Phương Vy Idol
#
# 2
#
#
# Hieu Tran Music Producer
#
# Tôi đưa em sang sông - Hà Anh Tuấn
#
# 2
#
#
# Hieu Tran Music Producer
#
# Tình bơ vơ - Hà Anh Tuấn
#
# 2
#
#
# Hieu Tran Music Producer
#
# Rong Rêu - Hà Anh Tuấn
#
# 2
#
#
# Hieu Tran Music Producer
#
# Liên khúc Trái tim ngục tù - Trái tim mùa đông - Hà Anh Tuấn
#
# 2
#
#
# Hieu Tran Music Producer
#
# Lại gần hôn anh - Hà Anh Tuấn
#
# 2
#
#
# Hieu Tran Music Producer
#
# Kiếp đam mê - Hà Anh Tuấn
#
# 2
#
#
# Hieu Tran Music Producer
#
# Comme Toi - Hà Anh Tuấn
#
# 2
#
#
# Hieu Tran Music Producer
#
# Cỏ Úa - Hà Anh Tuấn & Phương Linh
#
# 2
#
#
# Hieu Tran Music Producer
#
# Bao giờ biết tương tư - Hà Anh Tuấn
#
# 2
#
#
# Hieu Tran Music Producer
#
# What A Wonderful World - Phương Vy Idol - Chào 2019
#
# 2
#
#
# Hieu Tran Music Producer
#
# Vui như Tết - Phương Vy Idol
#
# 2
#
#
# Hieu Tran Music Producer
#
# Giáng Sinh Kỷ Niệm - Phương Linh
#
# 3
#
#
# Hieu Tran Music Producer
#
# Hai Ta - Phương Vy Idol & Sean Trace
#
# 2
#
#
# Hieu Tran Music Producer
#
# Nếu mai chia tay ( Hieu Tran Chill RnB Version) - Monstar Ft. Amee
#
# 3
#
#
# Hieu Tran Music Producer
#
# Đường xa ướt mưa - Phương Vy Idol & Sean Trace
#
# 3
#
#
# Hieu Tran Music Producer
#
# Khi người yêu tôi khóc - Phương Vy Idol & Family
#
# 2
#
#
# Hieu Tran Music Producer
#
# Lỡ Yêu - Trang Thiên
#
# 3
#
#
# Hieu Tran Music Producer
#
# No Boyfriend - Hoàng Yến Chibi
#
# 3
#
#
# Hieu Tran Music Producer
#
# Anh Muốn Cưới Em Một Tỉ Lần - Anh Tuấn ( MTV Band)
#
# 2
#
#
# Hieu Tran Music Producer
#
# Giai Điệu Tự Hào - MTV Band Ft. Hieu Tran
#
# 2
#
#
# Hieu Tran Music Producer
#
# Xuân Yên Bình - Vũ Thảo My
#
# 2
#
#
# Hieu Tran Music Producer
#
# Và Tôi Hát - MONSTAR
#
# 2
#
#
# Hieu Tran Music Producer
#
# Và Tôi Hát (Acoustic)- MONSTAR
#
# 2
#
#
# Hieu Tran Music Producer
#
# Câu chuyện làm quen - Quốc Thiên
#
# 3
#
#
# Hieu Tran Music Producer
#
# Ngày Hôm Qua - Vũ Cát Tường
#
# 3
#
#
# Hieu Tran Music Producer
#
# Gạt đi nước mắt - Noo Phước Thịnh, Tonny Viet ( Asia Song Festival 2016 - Hiếu Trần Remix)
#
# 3
#
#
# Hieu Tran Music Producer
#
# Sắc màu - Lê Hoàng Phong (X-Factor 2016)
#
# 3
#
#
# Hieu Tran Music Producer
#
# Mơ - Lê Hoàng Phong ( X-Factor 2016)
#
# 2
#
#
# Hieu Tran Music Producer
#
# Em và tôi - Lê Hoàng Phong (X-Factor 2016)
#
# 3
#
#
# Hieu Tran Music Producer
#
# Mình yêu từ bao giờ ( Hieu Tran The Remix Season 2) - Ngô Kiến Huy
#
# 2
#
#
# Hieu Tran Music Producer
#
# Medley Chỉ là giấc mơ - Góc tối ( Hieu Tran The Remix Season 2)- Ngô Kiến Huy
#
# 3
#
#
# Hieu Tran Music Producer
#
# Tình Yêu Mùa Xuân - Phương Linh
#
# 3
#
#
# Hieu Tran Music Producer
#
# Opening M-TP AMBITION Hanoi & Con Mua Ngang Qua ( Hieu Tran Remix)
#
# 3
#
#
# Hieu Tran Music Producer
#
# Như Ngày Hôm Qua - Sơn Tùng MTP
#
# 3
#
#
# Hieu Tran Music Producer
#
# Giáng Sinh Kỷ Niệm - Phương Linh - Teaser
#
# 2
#
#
# Hieu Tran Music Producer
#
# Skyfall - Adele Cover - Hieu Tran Remix
#
# 2
#
#
# Hieu Tran Music Producer
#
# Kẻ tội đồ - Wowy
#
# 3
#
#
# Hieu Tran Music Producer
#
# Là Mẹ của con - Hoàng Yến Chibi
#
# 2
#
#
# Hieu Tran Music Producer
#
# Như Phút Ban Đầu - Tiến Việt Ft. Yến Lê
#
# 3
#
#
# Hieu Tran Music Producer
#
# Feel It - Phương Vy Ft. Wowy
#
# 2
#
#
# Hieu Tran Music Producer
#
# Điều vô lý thứ nhất - Nguyên Hà
#
# 3
#
#
# Hieu Tran Music Producer
#
# Thằng Cuội - Tiểu Đình Acapella Onetake
#
# 3
#
#
# Hieu Tran Music Producer
#
# Part Of My World - Phương Vy ( Bossa Nova Version)
#
# 3
#
#
# Hieu Tran Music Producer
#
# Điều không thể nói - Phương Vy
#
# 2
#
#
# Hieu Tran Music Producer
#
# Tình nghĩa đôi ta chỉ thế thôi - Thiên Minh
#
# 2
#
#
# Hieu Tran Music Producer
#
# Nơi tình yêu bắt đầu - Bùi Anh Tuấn - Hiếu Trần Mastering Version
#
# 2
#
#
# Hieu Tran Music Producer
#
# Medley Chỉ có em - Người tình người đẹp xinh xinh - Thiên Minh
#
# 2
#
#
# Hieu Tran Music Producer
#
# Royal - Lorde - Hiếu Trần Reggae Remix
#
# 2
#
#
# Hieu Tran Music Producer
#
# Đắn Đo - Hồ Ngọc Hà - " Hiếu Trần Mastering " Version
#
# 2
#
#
# Hieu Tran Music Producer
#
# 24 giờ 7 ngày - Tiến Việt
#
# 2
#
#
# Hieu Tran Music Producer
#
# Swing it up - Phương Vy
#
# 3
#
#
# Hieu Tran Music Producer
#
# Môi tím - Phương Vy
#
# 2
#
#
# Hieu Tran Music Producer
#
# Nối vòng tay lớn EDM - Hiếu Trần Ft. Hà Anh Tuấn
#
# 2
#
#
# Hieu Tran Music Producer
#
# All About That Bass - Meghan Trainor - Tieu Dinh Cover
#
# 2
#
#
# Hieu Tran Music Producer
#
# Call Me - Blondie - Tiểu Đình cover - One Take
#
# 2
#
#
# Hieu Tran Music Producer
#
# Joe Le Taxi - Hieu Tran Ft. CindyV
#
# 2
#
#
# Hieu Tran Music Producer
#
# Tattoo song
#
# 2
#
#
# Hieu Tran Music Producer
#
# Bad Romance - Hiếu Trần
#
# 3
# L2Share♫140
#
# GIRIBOY (기리보이) - 내일은 없다 (Feat. lIlBOI, nafla) (No Tomorrow)
#
# 3
#
#
# L2Share♫140
#
# GIRIBOY (기리보이) - 우린 결국 그렇게 (Feat. Seori) (That's How We Ended Up)
#
# 3
#
#
# L2Share♫140
#
# GIRIBOY (기리보이) - 엉망진창 (What A Mess)
#
# 3
#
#
# L2Share♫140
#
# GIRIBOY (기리보이) - 그리고 돌아섰다 (You Turned Around)
#
# 3
#
#
# L2Share♫140
#
# NCT 127 - Sticker
#
# 3
#
#
# L2Share♫140
#
# NCT 127 - Lemonade
#
# 3
#
#
# L2Share♫140
#
# MAMAMOO (마마무) - 하늘 땅 바다만큼 (mumumumuch)
#
# 3
#
#
# L2Share♫140
#
# MAMAMOO (마마무) - Happier than Ever (분명 우린 그땐 좋았었어)
#
# 3
#
#
# L2Share♫140
#
# Han Yo Han (한요한) - 이게 나야 (Feat. CHANGMO (창모)) (This Is Me)
#
# 3
#
#
# L2Share♫140
#
# Lee Mujin (이무진) - 가을 타나 봐 (Fall in Fall)
#
# 3
#
#
# L2Share♫140
#
# PURPLE KISS (퍼플키스) - Zombie
#
# 3
#
#
# L2Share♫140
#
# I.M (아이엠) - Loop
#
# 3
#
#
# L2Share♫140
#
# LOONA (이달의 소녀) - Not Friends (Sung by 희진, 김립, 진솔, 이브 (HeeJin, Kim Lip, JinSoul, Yves) (Prod. 라이언전)
#
# 3
#
#
# L2Share♫140
#
# KEY (키) - Hate that... (Feat. 태연 (TAEYEON))
#
# 3
#
#
# L2Share♫140
#
# LeeHi (이하이) - ONLY
#
# 3
#
#
# L2Share♫140
#
# JAY B - B.T.W (Feat. 박재범) (Prod. Cha Cha Malone)
#
# 3
#
#
# L2Share♫140
#
# Loco (로꼬) - 이대로만 (Feat. 죠지 (George) (Just Like This)
#
# 3
#
#
# L2Share♫140
#
# KWON EUN BI (권은비) - Door
#
# 3
#
#
# L2Share♫140
#
# Brave Girls (브레이브걸스) - After We Ride (술버릇 (운전만해 그후))
#
# 3
#
#
# L2Share♫140
#
# VERIVERY - TRIGGER
#
# 3
#
#
# L2Share♫140
#
# Piano Man (피아노맨) - 네 노래 (Your Song)
#
# 3
#
#
# L2Share♫140
#
# HA SUNG WOON 하성운X펀치 (Punch) - 자니 (Johnny) (Cyworld BGM 2021)
#
# 3
#
#
# L2Share♫140
#
# CIX (씨아이엑스) - WAVE
#
# 3
#
#
# L2Share♫140
#
# TXT - LO$ER=LO♡ER
#
# 3
#
#
# L2Share♫140
#
# TXT - MOA Diary (Dubaddu Wari Wari) (교환일기 (두밧두 와리와리))
#
# 3
#
#
# L2Share♫140
#
# TXT - 0X1=LOVESONG (I Know I Love You) feat. Seori (Emocore Mix)
#
# 3
#
#
# L2Share♫140
#
# Red Velvet (레드벨벳) - Pose
#
# 3
#
#
# L2Share♫140
#
# Red Velvet (레드벨벳) - Knock On Wood
#
# 3
#
#
# L2Share♫140
#
# Red Velvet (레드벨벳) - Better Be
#
# 3
#
#
# L2Share♫140
#
# Red Velvet (레드벨벳) - Pushin' N Pullin'
#
# 3
#
#
# L2Share♫140
#
# Red Velvet (레드벨벳) - 다시, 여름 (Hello, Sunset)
#
# 3
#
#
# L2Share♫140
#
# Lee Young Ji (이영지) - HATE ME (Feat. 유라 (youra)) (Prod. WOOGIE (우기))
#
# 3
#
#
# L2Share♫140
#
# Standing Egg (스탠딩 에그) - 무슨 생각해 (What Are You Thinking About)
#
# 3
#
#
# L2Share♫140
#
# ONF - Summer Poem (여름 시) / Summer Shape (여름의 모양) / Dry Ice (여름의 온도) / Summer End (여름의 끝)
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# mashup // cho mình em - daydreams - treasure // binz ft soobin ft rhymastic
#
# 2
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# an thần // lofi slowed - low G ft thắng ( ngọt )
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# biết em // slowed - lynk nguyen
#
# 2
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# không phải tại nó // lạc - mai ngô ft rhymastic
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# tell ur mom II // slowed - winno
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# gác lại âu lo // slowed - da lab ft miu le
#
# 2
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# ngày mai em đi // slowed - soobin hoàng sơn
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# chúng ta của hiện tại x giọt nước mắt muộn màng // mashup
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# love 08 // slowed - duongG
#
# 2
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# 𝗯𝗮𝗯𝘆 𝗶 𝘁𝗼𝗹𝗱 𝘆𝗼𝘂 // 𝘀𝗹𝗼𝘄𝗲𝗱 - 𝗺𝗼𝗻𝘀𝘁𝗮𝗿
#
# 2
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# từ thích thích thành thương thương // slowed - amee ft Hoàng Dũng
#
# 2
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# một giấc mơ // slowed - Vũ
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# thanh xuân // slowed - Dalab
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# anh sẽ luôn thật gần // slowed
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# hãy ra khỏi người đó đi // slowed - Phan Mạnh Quỳnh
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# 𝘮𝘴 𝘮𝘢𝘺 // 𝘴𝘭𝘰𝘸𝘦𝘥 - 𝘊𝘩𝘪𝘭𝘭𝘪𝘦𝘴
#
# 2
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# em đừng khóc // slowed - Chillies
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# 𝒕𝒊𝒏𝒉 𝒚𝒆𝒖 𝒍𝒂 𝒄𝒂𝒊 𝒈𝒊 ?
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# do for love // slowed - bray
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# đông kiếm em // slowed - vũ
#
# 2
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# mot nguoi vi em (midnight) // slowed - WEAN
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# em ơi, anh ở đây !! it's for u
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# 𝙀𝙢𝙢𝙚 // 𝙚𝙢,𝙩𝙤𝙞 // 𝙨𝙡𝙤𝙬𝙚𝙙 -  𝙙𝙖𝙩 𝙂
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# vườn mây // slowed - Madihu
#
# 2
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# bài ca mlem // slowed // o buồn ft jay bach
#
# 2
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# bốc bát họ // ver beat đen đá không đường // bình gold 💵
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# thức giấc // slowed - Dalab
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# một người vì em // slowed // Wean feat. ShiGGa Shay
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# nắm đôi bàn tay // slowed - kay trần
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# bỏ em vào balo // slowed lofi
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# thích em hơi nhiều // slowed lofi - Wren Evans
#
# 2
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# em muốn lái chị [ver beat] đen đá không đường // bình gold 💵
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# renai circulation x 2 phút hơn
#
# 2
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# tôi sẽ là ai ? - Vinh Khuất
#
# 2
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# Type Beat Lo-fi - 𝙷𝚊𝚢 𝚝𝚛𝚊𝚘 𝚌𝚑𝚘 𝚊𝚗𝚑
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# Muộn Rồi Mà Sao Còn [ FULL audio ] - Sơn Tùng M-TP
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# bà con ai đang gặp vấn đề về sương khớp Lofi
#
# 2
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# tình EM là đại dương - SƠN TÙNG M-TP [ Lofi Version ]
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# chúng ta của hiện tại [ Piano cover ] - Sơn Tùng M-TP
#
# 2
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# sorry i like you but it's mix cực chill
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# gói tình em rồi về Lofi - Phùng Khánh Linh
#
# 3
#
#
# 𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
#
# Vũ cover At My Worts - Pink Sweat
#
# 2
#
#
# Nan Kohsoom Ho
#
# อุ๋งๆ - PORZAX
#
# 2
#
#
# Nan Kohsoom Ho
#
# ให้ฉันดูแลเธอ  - แหนม รณเดช (cover)
#
# 2
#
#
# Nan Kohsoom Ho
#
# Biết em - Lynk Nguyễn
#
# 3
#
#
# Nan Kohsoom Ho
#
# ดีแล้วเธอ - ANOTHERBOYTJ
#
# 2
#
#
# Nan Kohsoom Ho
#
# ลืมไปหรือเปล่า - Cover by Quang Hùng MasterD
#
# 2
#
#
# Nan Kohsoom Ho
#
# ลืมไปหรือเปล่า - ZaadOat studio (cover)
#
# 2
#
#
# Nan Kohsoom Ho
#
# JayiJi - รัูไหม (Do u know)
#
# 2
#
#
# Nan Kohsoom Ho
#
# แล้วหลาวไอโบ - WONDERFRAME x YINWAR
#
# 2
#
#
# Nan Kohsoom Ho
#
# รู้ (know) - bonnadol x YIN ANW
#
# 2
#
#
# Lkang
#
# một cú lừa cover (remix sập nguồn) - StormP
#
# 2
#
#
# Lkang
#
# [DCOD] NGTANOISE (Người ta nói - remake) | VSOUL x MFREE x TUYEN VO|
#
# 3
#
#
# yafu
#
# GPS - NIDEBIG ft BINQANG , PURR ( PROD : HS YAFU )
#
# 3
#
#
# yafu
#
# 01 Playboi Carti Mix
#
# 3
#
#
# yafu
#
# So' 1
#
# 2
#
#
# yafu
#
# Burberry
#
# 3
#
#
# yafu
#
# rEddd
#
# 3
#
#
# yafu
#
# I Luv U
#
# 3
#
#
# yafu
#
# Hi.
#
# 3
#
#
# Đặng Gia Linh
#
# 3107-3 ( Cover by Mickey & Thuy An )
#
# 3
#
#
# Đặng Gia Linh
#
# Tình Đơn Phương Nguyên Ft. KOO
#
# 3
#
#
# Đặng Gia Linh
#
# Chiều nay không có mưa bay - Cover
#
# 3
#
#
# Đặng Gia Linh
#
# 3107 cover (demo )
#
# 3
#
#
# Đặng Gia Linh
#
# Obito Ft. Hnhngan Live YOUR SMILE - Emma X Seachains X Obito
#
# 3
#
#
# Đặng Gia Linh
#
# Thói Quen- Hoàng Dũng
#
# 3
#
#
# Đặng Gia Linh
#
# CHÚNG TA CỦA HIỆN TẠI l SƠN TÙNG MT-P ( nguyên. cover )
#
# 3
#
#
# Đặng Gia Linh
#
# Nàng Thơ - Hoàng Dũng ( Nguyên. Cover )
#
# 3
#
#
# Đặng Gia Linh
#
# Chiếc Khăn Gió Ấm - Nguyễn Hải Vân (Cover)
#
# 3
#
#
# Đặng Gia Linh
#
# Đừng Vì Anh Mà Khóc - Quang Hùng MasterD ( Nguyên. Cover )
#
# 3
#
#
# Đặng Gia Linh
#
# MAI cover- Đã Lỡ Yêu Em Nhiều
#
# 3
#
#
# Đặng Gia Linh
#
# Chờ Anh Nhé- Hoàng Dũng
#
# 3
#
#
# VUX
#
# HẠNH PHÚC BỎ RƠI EM (lofi ver. by VUX) - HƯƠNG LY | NGÔ QUYỀN LINH COVER
#
# 2
#
#
# VUX
#
# NGƯỜI LẠ THOÁNG QUA (VUX REMIX) - ĐINH TÙNG HUY
#
# 3
#
#
# VUX
#
# EM HÁT AI NGHE (VUX REMIX) - ORANGE
#
# 3
#
#
# VUX
#
# 3107-3 (lofi ver. by VUX) - W/n x Nâu x Duongg x Titie
#
# 3
#
#
# VUX
#
# SAI CÁCH YÊU (VUX REMIX) - LÊ BẢO BÌNH //demo
#
# 3
#
#
# VUX
#
# SÀI GÒN HÔM NAY MƯA (lofi ver. by VUX) - JSOL & HOÀNG DUYÊN
#
# 3
#
#
# VUX
#
# ANH CÓ MUỐN ĐƯA EM VỀ KHÔNG (VUX REMIX) - NGÔ LAN HƯƠNG
#
# 3
#
#
# VUX
#
# PHẢI CHĂNG EM ĐÃ YÊU (VUX REMIX) - JUKY SAN ft. REDT
#
# 3
#
#
# VUX
#
# TÌNH BẠN DIỆU KỲ (VUX REMIX) - Ricky Star x Lăng LD x Amee
#
# 3
#
#
# VUX
#
# BIGCITYBOI ( VUX REMIX ) - Touliver x Binz
#
# 3
#
#
# VUX
#
# Hoa Nở Không Màu ( VUX REMIX ) - Hoài Lâm //demo
#
# 3
#
#
# VUX
#
# CỐ GIANG TÌNH ( VUX Remix ) - Phát Hồ x JokeS Bii ft DinhLong
#
# 3
#
#
# VUX
#
# CHÂN ÁI (VUX Remix) - Orange x Khói x Châu Đăng Khoa
#
# 3
#
#
# 1967 Music
#
# L.O.V.E - Nguyên x R-IN
#
# 2
#
#
# 1967 Music
#
# Tell Ur Mom II (Remix)Winno ft Heily
#
# 3
#
#
# 1967 Music
#
# Tell Ur Mom II - Winno ft. Heily
#
# 2
#
#
# 1967 Music
#
# NHẮN TỚI KHOẢNG TRỜI EM - QUÂN A.P
#
# 3
#
#
# 1967 Music
#
# LUV U 300.000 Kms [Lofi] DRUM7
#
# 2
#
#
# 1967 Music
#
# LUV U 300.000 Kms - DRUM7
#
# 2
#
#
# 1967 Music
#
# Lời Thanh Xuân Chưa Nói - Night
#
# 3
#
#
# 1967 Music
#
# Cứ nói yêu lần này - LiL Z Poet
#
# 3
#
#
# 1967 Music
#
# Falling [Lofi] Graykee x Dứa
#
# 2
#
#
# 1967 Music
#
# Bao Lâu Ta Lại Yêu Một Người [Lofi] - Doãn Hiếu
#
# 2
#
#
# 1967 Music
#
# Cuộc Điện Thoại - Tùa ft. CM1X
#
# 2
#
#
# 1967 Music
#
# Nếu Anh Thấy Lòng Mình Yếu Đuối -Tùa ft. CM1X
#
# 3
#
#
# 1967 Music
#
# Viên Đá Nhỏ - Hương Ly
#
# 2
#
#
# 1967 Music
#
# Ký Ức Vỡ Đôi [Lofi] Trần Khánh Huyền (Cover)
#
# 2
#
#
# 1967 Music
#
# Liệu Còn Mai - Nguyễn Thị Thảo x Non Hanta
#
# 3
#
#
# 1967 Music
#
# Liệu còn mai? [Lofi] Nguyễn Thị Thảo ft. Non Hanta
#
# 2
#
#
# 1967 Music
#
# 3107-3 [Lofi] W/n x Nâu x Duongg x Titie
#
# 3
#
#
# 1967 Music
#
# Cho Nhau Một Lời Hứa - LUNY Vũ Duy Anh ft. Quang Hùng MasterD
#
# 2
#
#
# 1967 Music
#
# Cho Nhau Một Lời Hứa [Lofi] - LUNY Vũ Duy Anh x Quang Hùng MasterD
#
# 2
#
#
# 1967 Music
#
# Có Hẹn Với Thanh Xuân [Remix] - Monstar ft. AnhVu
#
# 3
#
#
# 1967 Music
#
# 530 - Mơ ft Tipss
#
# 2
#
#
# 1967 Music
#
# Drunk - Kean
#
# 3
# Ronniboi
#
# Lang Nghe - Hasted ft. Bình Minh (prod. by Ronniboi)
#
# 3
#
#
# Ronniboi
#
# Honesty - Pink Sweat$ (cover)
#
# 3
#
#
# Ronniboi
#
# Distance - Kim Kunni (Prod. by Ronniboi)
#
# 3
#
#
# Ronniboi
#
# Coffee Cup (feat. Small D)
#
# 3
#
#
# Ronniboi
#
# Tim Dau (feat. Onekay, SOS)
#
# 3
#
#
# Ronniboi
#
# Confident (feat. T.R.I)
#
# 3
#
#
# Ronniboi
#
# Little Heart - Kim Kunni (Prod. by Ronniboi)
#
# 3
#
#
# Ronniboi
#
# Redbone
#
# 3
#
#
# Ronniboi
#
# People 2
#
# 3
#
#
# Ronniboi
#
# KISS KISS - Ronniboi ft. Wxrdie (prod. by Jsdrmns)
#
# 3
#
#
# Ronniboi
#
# Fall For Your Type
#
# 3
#
#
# Ronniboi
#
# I'm Sorry (feat. Lockie)
#
# 3
#
#
# Ronniboi
#
# Khi co don em nho ai
#
# 3
#
#
# Ronniboi
#
# Used To Missing You (Prod. by Jsdrmns)
#
# 3
#
#
# Ronniboi
#
# I wonder - Ronniboi ft. Misa
#
# 3
#
#
# Ronniboi
#
# Self-Control
#
# 3
#
#
# Ronniboi
#
# Pray
#
# 3
#
#
# Ronniboi
#
# Last Christmas (feat. Onekay)
#
# 3
#
#
# Ronniboi
#
# Heaven - Ronniboi ft. Kim Chi (prod. by Jsdrmns)
#
# 3
#
#
# Ronniboi
#
# I'll Remember You
#
# 3
#
#
# Ronniboi
#
# You're Gonna Live Forever In Me
#
# 3
#
#
# Ronniboi
#
# I have to go, she said
#
# 3
#
#
# Ronniboi
#
# Love is in the air
#
# 3
#
#
# Ronniboi
#
# Sound of A Broken Heart
#
# 3
#
#
# Ronniboi
#
# Springtime
#
# 3
#
#
# Ronniboi
#
# Moonlight
#
# 3
#
#
# Ronniboi
#
# You Give Me Butterflies
#
# 3
#
#
# Ronniboi
#
# The Way
#
# 3
#
#
# Ronniboi
#
# Crazy for you (Instrumental + hook)
#
# 3
#
#
# Ronniboi
#
# If She Knows (Ronniboi remix)
#
# 3
#
#
# Ronniboi
#
# Crazy for you (feat. JayV)
#
# 3
#
#
# Ronniboi
#
# Be with you (2013)
#
# 3
#
#
# Ronniboi
#
# Time of life
#
# 3
#
#
# Ronniboi
#
# Forwards - Ronniboi ft. Jayz
#
# 3
#
#
# Ronniboi
#
# Another Chance (feat. JayV)
#
# 3
#
#
# Ronniboi
#
# Em - Ronniboi ft. Tim
#
# 3
#
#
# Ronniboi
#
# Tinh Anh (2013)
#
# 3
#
#
# Ronniboi
#
# night stars
#
# 3
#
#
# Ronniboi
#
# raindrops.
#
# 3
#
#
# Ronniboi
#
# off the ground.
#
# 3
#
#
# Ronniboi
#
# Butterflies (feat. JayV)
#
# 3
#
#
# Ronniboi
#
# One More Try (2013)
#
# 3
#
#
# Ronniboi
#
# People
#
# 3
#
#
# Ronniboi
#
# Amor Fati - Epik High cover (demo)
#
# 2
#
#
# Ronniboi
#
# Mama
#
# 3
#
#
# Ronniboi
#
# I Miss You(demo)
#
# 2
#
#
# Ronniboi
#
# Crying over you (cover/remix) - Ronniboi ft. Trod
#
# 3
#
#
# Ronniboi
#
# Twenty
#
# 2
#
#
# Ronniboi
#
# Ngay xua em den (remix)
#
# 3
#
#
# Ronniboi
#
# The Motion - Drake (cover/remix)
#
# 3
#
#
# Ronniboi
#
# Hold on, we're going home (cover)
#
# 2
#
#
# Ronniboi
#
# Bad Boy - English cover
#
# 3
#
#
# Ronniboi
#
# Rainydays
#
# 2
#
#
# Ronniboi
#
# Memories - Ron Nguyen ft Ron Huynh
#
# 3
#
#
# Ronniboi
#
# CLARITY - ZEDD (RONNIBOII REMIX)
#
# 2
#
#
# Ronniboi
#
# There's you, there's me(demo)
#
# 2
#
#
# Ronniboi
#
# Yesterday (original) - Ron Nguyen
#
# 2
#
#
# Ronniboi
#
# Don't forget me
#
# 2
#
#
# Ronniboi
#
# Lighters - Ronniboi ft. Jayv
#
# 2
#
#
# Hawys.
#
# tlinh - GÁI ĐỘC THÂN (HAWYS REMIX)
#
# 2
#
#
# Hawys.
#
# vô tình ta lạc mất nhau..
#
# 3
#
#
# Hawys.
#
# Chợt Tỉnh Giấc - Quang Anh Rhyder (Lo-fi ver by Hawys)
#
# 2
#
#
# Hawys.
#
# HIEUTHUHAI - NGHE NHƯ TÌNH YÊU (FELIKS ALVIN REMIX) | HAWYS EDIT
#
# 3
#
#
# Hawys.
#
# Moonlight Romance (Lo-fi Edit)
#
# 3
#
#
# Hawys.
#
# Da LAB - THỨC GIẤC (HAWYS REMIX)
#
# 3
#
#
# Hawys.
#
# HOÀNG TÔN x LYHAN - TÌNH YÊU NGỦ QUÊN (HAWYS 80s REMIX)
#
# 3
#
#
# Hawys.
#
# JSOL x Hoàng Duyên - Sài Gòn Hôm Nay Mưa (Lo-fi ver by Hawys)
#
# 3
#
#
# Hawys.
#
# Orange x Hoàng Dũng - Khi Em Lớn (Lo-fi ver by Hawys)
#
# 3
#
#
# Hawys.
#
# đơn phương là gì em nhỉ?
#
# 3
#
#
# Hawys.
#
# SƠN TÙNG M-TP | MUỘN RỒI MÀ SAO CÒN (HAWYS REMIX)
#
# 3
#
#
# Hawys.
#
# Anh có bàn tay để nắm tất cả nhưng không thế nắm được tay em..
#
# 3
#
#
# Hawys.
#
# 𝙪 𝙖𝙧𝙚 𝙖𝙡𝙡 𝙞 𝙩𝙝𝙞𝙣𝙠 𝙖𝙗𝙤𝙪𝙩 𝙖𝙩 𝙣𝙞𝙜𝙝𝙩..
#
# 3
#
#
# Hawys.
#
# lovesick 1402
#
# 2
#
#
# Hawys.
#
# Anh chỉ muốn anh gần em hơn..
#
# 3
#
#
# Hawys.
#
# có công mài sắt, có ngày iu em
#
# 3
#
#
# Hawys.
#
# vì con tim chưa bao giờ nghe theo lí trí..
#
# 2
#
#
# Hawys.
#
# Bozitt - Những gì anh nói (Lofi ver by Hawys)
#
# 3
#
#
# Hawys.
#
# L.Y.2
#
# 3
#
#
# Hawys.
#
# Xe Đạp - Charles Huynh Cover (Lo-fi ver by Hawys)
#
# 3
#
#
# Hawys.
#
# need u
#
# 3
#
#
# Hawys.
#
# hawys - sunrise
#
# 3
#
#
# Hawys.
#
# p l a y  d a t e (Lofi edit)
#
# 3
#
#
# Hawys.
#
# JUSTATEE x TIÊN TIÊN - CẦN GÌ HƠN (HAWYS X NGHIANGUYEN. REMIX)
#
# 3
#
#
# Hawys.
#
# PHÁO X WACK - HAI PHÚT HƠN (HAWYS REMIX)
#
# 3
#
#
# Hawys.
#
# Vẫn là QuaBanh nhưng..
#
# 3
#
#
# Hawys.
#
# Anh cho em mùa xuân (Lo-fi ver by Hawys)
#
# 3
#
#
# Hawys.
#
# 𝘔𝘦𝘮𝘰𝘳𝘪𝘦𝘴.. (Free Lo-Fi Type Beat)
#
# 3
#
#
# Hawys.
#
# đã lỡ iu em nhìu (hawys retro rimex)
#
# 3
#
#
# Hawys.
#
# Thắc Mắc (Lo-fi ver by Hawys) - Có lẽ em đã khóc rất nhiều..
#
# 3
#
#
# Hawys.
#
# Ｒｅａｌ ｆｒｉｅｎｄｓ(lofi ver by hawys)
#
# 3
#
#
# Hawys.
#
# HOAPROX ft XESI - NOI EM MUON TOI (HAWYS REMIX)
#
# 3
#
#
# Hawys.
#
# HAWYS - SEE THE LIGHT (FREE DOWNLOAD!)
#
# 3
#
#
# Hawys.
#
# Việt - Hơn Cả Mây Trời (lofi ver by hawys)
#
# 3
#
#
# Hawys.
#
# Thịnh Suy - Một đêm say (lo-fi ver by hawys)
#
# 3
#
#
# Hawys.
#
# 𝙚𝙢 𝙣𝙝𝙪 𝙗𝙤𝙣𝙜 𝙝𝙤𝙖
#
# 3
#
#
# Hawys.
#
# Maroon5 - Girls Like You (Hawys Remix)
#
# 3
#
#
# TIEN TIEN
#
# DAMN GOOD
#
# 3
#
#
# TIEN TIEN
#
# DAMN GOOD - TIEN TIEN X AazuKi
#
# 3
#
#
# TIEN TIEN
#
# LO XA - TIEN TIEN
#
# 3
#
#
# TIEN TIEN
#
# I DON'T WANNA MISS YOU - TIEN TIEN x TRANG
#
# 3
#
#
# TIEN TIEN
#
# VE VOI EM DI - (DUCKV REMIX)
#
# 3
#
#
# TIEN TIEN
#
# CAN GI HON? - TIEN TIEN x JUSTATEE
#
# 3
#
#
# TIEN TIEN
#
# INTRO - EP "NHAC CUA CHUNG"
#
# 3
#
#
# TIEN TIEN
#
# CHAC ANH ĐANG (PIANO) - TIEN TIEN x TRANG [EP "NHAC CUA CHUNG"]
#
# 3
#
#
# TIEN TIEN
#
# CAU TRA LOI - TIEN TIEN x TRANG
#
# 3
#
#
# TIEN TIEN
#
# TA CAM ON - TIEN TIEN
#
# 3
#
#
# TIEN TIEN
#
# DAU CAN MOT BAI CA TINH YEU
#
# 3
#
#
# TIEN TIEN
#
# CHILL WITH ME - TIEN TIEN (ALBUM 2018)
#
# 3
#
#
# TIEN TIEN
#
# QUA NGAY MAI - TIEN TIEN
#
# 3
#
#
# TIEN TIEN
#
# YOU USED TO BE "MY EVERYTHING"
#
# 3
#
#
# TIEN TIEN
#
# VE VOI EM DI - DEMO
#
# 3
#
#
# TIEN TIEN
#
# DEMO 2014 - MY EVERYTHING - DEEPHOUSE
#
# 3
#
#
# Hawys.
#
# tlinh - GÁI ĐỘC THÂN (HAWYS REMIX)
#
# 2
#
#
# Hawys.
#
# vô tình ta lạc mất nhau..
#
# 3
#
#
# Hawys.
#
# Chợt Tỉnh Giấc - Quang Anh Rhyder (Lo-fi ver by Hawys)
#
# 2
#
#
# Hawys.
#
# HIEUTHUHAI - NGHE NHƯ TÌNH YÊU (FELIKS ALVIN REMIX) | HAWYS EDIT
#
# 3
#
#
# Hawys.
#
# Moonlight Romance (Lo-fi Edit)
#
# 3
#
#
# Hawys.
#
# Da LAB - THỨC GIẤC (HAWYS REMIX)
#
# 3
#
#
# Hawys.
#
# HOÀNG TÔN x LYHAN - TÌNH YÊU NGỦ QUÊN (HAWYS 80s REMIX)
#
# 3
#
#
# Hawys.
#
# JSOL x Hoàng Duyên - Sài Gòn Hôm Nay Mưa (Lo-fi ver by Hawys)
#
# 3
#
#
# Hawys.
#
# Orange x Hoàng Dũng - Khi Em Lớn (Lo-fi ver by Hawys)
#
# 3
#
#
# Hawys.
#
# đơn phương là gì em nhỉ?
#
# 3
#
#
# Hawys.
#
# SƠN TÙNG M-TP | MUỘN RỒI MÀ SAO CÒN (HAWYS REMIX)
#
# 3
#
#
# Hawys.
#
# Anh có bàn tay để nắm tất cả nhưng không thế nắm được tay em..
#
# 3
#
#
# Hawys.
#
# 𝙪 𝙖𝙧𝙚 𝙖𝙡𝙡 𝙞 𝙩𝙝𝙞𝙣𝙠 𝙖𝙗𝙤𝙪𝙩 𝙖𝙩 𝙣𝙞𝙜𝙝𝙩..
#
# 3
#
#
# Hawys.
#
# lovesick 1402
#
# 2
#
#
# Hawys.
#
# Anh chỉ muốn anh gần em hơn..
#
# 3
#
#
# Hawys.
#
# có công mài sắt, có ngày iu em
#
# 3
#
#
# Hawys.
#
# vì con tim chưa bao giờ nghe theo lí trí..
#
# 2
#
#
# Hawys.
#
# Bozitt - Những gì anh nói (Lofi ver by Hawys)
#
# 3
#
#
# Hawys.
#
# L.Y.2
#
# 3
#
#
# Hawys.
#
# Xe Đạp - Charles Huynh Cover (Lo-fi ver by Hawys)
#
# 3
#
#
# Hawys.
#
# need u
#
# 3
#
#
# Hawys.
#
# hawys - sunrise
#
# 3
#
#
# Hawys.
#
# p l a y  d a t e (Lofi edit)
#
# 3
#
#
# Hawys.
#
# JUSTATEE x TIÊN TIÊN - CẦN GÌ HƠN (HAWYS X NGHIANGUYEN. REMIX)
#
# 3
#
#
# Hawys.
#
# PHÁO X WACK - HAI PHÚT HƠN (HAWYS REMIX)
#
# 3
#
#
# Hawys.
#
# Vẫn là QuaBanh nhưng..
#
# 3
#
#
# Hawys.
#
# Anh cho em mùa xuân (Lo-fi ver by Hawys)
#
# 3
#
#
# Hawys.
#
# 𝘔𝘦𝘮𝘰𝘳𝘪𝘦𝘴.. (Free Lo-Fi Type Beat)
#
# 3
#
#
# Hawys.
#
# đã lỡ iu em nhìu (hawys retro rimex)
#
# 3
#
#
# Hawys.
#
# Thắc Mắc (Lo-fi ver by Hawys) - Có lẽ em đã khóc rất nhiều..
#
# 3
#
#
# Hawys.
#
# Ｒｅａｌ ｆｒｉｅｎｄｓ(lofi ver by hawys)
#
# 3
#
#
# Hawys.
#
# HOAPROX ft XESI - NOI EM MUON TOI (HAWYS REMIX)
#
# 3
#
#
# Hawys.
#
# HAWYS - SEE THE LIGHT (FREE DOWNLOAD!)
#
# 3
#
#
# Hawys.
#
# Việt - Hơn Cả Mây Trời (lofi ver by hawys)
#
# 3
#
#
# Hawys.
#
# Thịnh Suy - Một đêm say (lo-fi ver by hawys)
#
# 3
#
#
# Hawys.
#
# 𝙚𝙢 𝙣𝙝𝙪 𝙗𝙤𝙣𝙜 𝙝𝙤𝙖
#
# 3
#
#
# Hawys.
#
# Maroon5 - Girls Like You (Hawys Remix)
#
# 3
#
#
# TÙA
#
# Nếu Anh Thấy Lòng Mình Yếu Đuối - Tùa x CM1X
#
# 3
#
#
# TÙA
#
# Room 21 - Tùa x CM1X
#
# 3
#
#
# TÙA
#
# CTTLTT Live Session | Đôi lời | TÙA x Nghiia (Cover)
#
# 3
#
#
# TÙA
#
# CTTLTT Live Session | Liệu anh có nghe | TÙA (Cover)
#
# 2
#
#
# TÙA
#
# Cuộc Điện Thoại - Tùa x CM1X
#
# 3
#
#
# TÙA
#
# Điều Chưa Nói (Ballad Version) - Tùa x CM1X
#
# 3
#
#
# TÙA
#
# Mình Chẳng Thể Cùng Nhau - Tùa x CM1X
#
# 3
#
#
# TÙA
#
# Ngày Hôm Nay Của Anh Thế Nào - Tùa x Freaky x CM1X
#
# 3
#
#
# TÙA
#
# Điều Chưa Nói - Tùa x CM1X
#
# 3
#
#
# RPT Phongkhin
#
# XTC (feat. RPT MCK, tlinh & RPT Groovie) [Special Version]
#
# 3
#
#
# RPT Phongkhin
#
# MOJOSET
#
# 3
#
#
# RPT Phongkhin
#
# 1 set nhạc không nhớ đi diễn ở đâu nhưng mà được =))))))
#
# 3
#
#
# RPT Phongkhin
#
# vo van vkl
#
# 3
#
#
# RPT Phongkhin
#
# 5h kém 40 phút
#
# 3
#
#
# RPT Phongkhin
#
# demo linh tinh
#
# 3
#
#
# RPT Phongkhin
#
# Đừng,đưa cho anh..
#
# 3
#
#
# RPT Phongkhin
#
# 🤦‍♂️muộn rồi đi ngủ đi🤦‍♂️
#
# 3
#
#
# RPT Phongkhin
#
# #MusicRequestByFans - 01 : Prod by MinFee
#
# 3
#
#
# RPT Phongkhin
#
# m,i,d,9 demo
#
# 3
#
#
# RPT Phongkhin
#
# b o m a y t h i c h n o n h u t h e d a y 😕 s e o ?
#
# 3
#
#
# RPT Phongkhin
#
# myanh reallove Challenge
#
# 3
#
#
# RPT Phongkhin
#
# Dude !@#%$#%& mtfk
#
# 3
#
#
# RPT Phongkhin
#
# < < < L$D > > >
#
# 3
#
#
# RPT Phongkhin
#
# 555555555
#
# 3
#
#
# RPT Phongkhin
#
# Nhảy đê
#
# 3
#
#
# RPT Phongkhin
#
# [RPT x 95G]  SMO & Lil Wuyn - JUMP ( phongkhìn. remix )
#
# 3
#
#
# RPT Phongkhin
#
# Noel cua Phongkhin feat RPT MCK demo
#
# 3
#
#
# RPT Phongkhin
#
# As$4ap
#
# 3
#
#
# RPT Phongkhin
#
# Saturday & sunday
#
# 3
#
#
# RPT Phongkhin
#
# Andree Vô Tâm
#
# 3
#
#
# RPT Phongkhin
#
# Rapitality Cypher Tết - prod by rpt.phongkhin
#
# 3
#
#
# RPT Phongkhin
#
# Thủ Đô Cypher rmx - RPT MCK $ RPT Orijinn $ lf.low.g $ RZ Mas
#
# 3
#
#
# RPT Phongkhin
#
# thờ error
#
# 3
#
#
# RPT Phongkhin
#
# Error:102 mixset
#
# 3
#
#
# RPT Phongkhin
#
# for them/lover
#
# 3
#
#
# RPT Phongkhin
#
# Praise The Lord
#
# 3
#
#
# RPT Phongkhin
#
# Kota The Phongkhin
#
# 3
#
#
# RPT Phongkhin
#
# 1900 Hiphop Party #5 : CDSL "Count the blessings"
#
# 3
#
#
# RPT Phongkhin
#
# PHÁT ĐIÊN !!!
#
# 3
#
#
# RPT Phongkhin
#
# VDLYER flip flip
#
# 3
#
#
# RPT Phongkhin
#
# blinding line
#
# 3
#
#
# RPT Phongkhin
#
# stuck with you
#
# 3
#
#
# RPT Phongkhin
#
# i'm so tired ..
#
# 3
#
#
# RPT Phongkhin
#
# tonghopnhacnhieuthangtruoc
#
# 3
#
#
# RPT Phongkhin
#
# Tlinh - Thích quá rùi nà feat. trungtran (instrumental)
#
# 3
#
#
# RPT Phongkhin
#
# Đi Lò Kò
#
# 3
#
#
# RPT Phongkhin
#
# Rap cham thoy phien ban lac lu.
#
# 3
#
#
# RPT Phongkhin
#
# khongchoido
#
# 3
#
#
# RPT Phongkhin
#
# Tlinh - Thích Quá Rùi Nà ft. Trung Trần (prod by @rpt.phongkhin )
#
# 3
#
#
# RPT Phongkhin
#
# Wxrdie - THE PARTY NEVER ENDS ft.PrettyXIX , 2PILLZ (pacman flip)
#
# 3
#
#
# RPT Phongkhin
#
# Baby i'm Good - Kim Chi Sun (pac rmx)
#
# 3
#
#
# RPT Phongkhin
#
# happy năm con chuột
#
# 3
#
#
# RPT Phongkhin
#
# noi da ga - kha ba travis
#
# 3
#
#
# RPT Phongkhin
#
# milkshake(reup+remaster)
#
# 2
#
#
# RPT Phongkhin
#
# OG mixtape
#
# 3
#
#
# RPT Phongkhin
#
# "C Minor"
#
# 3
#
#
# RPT Phongkhin
#
# hallelujah
#
# 3
#
#
# RPT Phongkhin
#
# im so lost w/o you
#
# 3
#
#
# RPT Phongkhin
#
# all-time bae flip
#
# 3
#
#
# RPT Phongkhin
#
# Đi Đua Đê
#
# 3
#
#
# RPT Phongkhin
#
# bad guy
#
# 3
#
#
# RPT Phongkhin
#
# CDSL'S PARTY:MOVEMENT MIXSET
#
# 3
#
#
# RPT Phongkhin
#
# ny cà fê
#
# 3
#
#
# RPT Phongkhin
#
# ok
#
# 3
#
#
# RPT Phongkhin
#
# lazyfriday.
#
# 3
#
#
# RPT Phongkhin
#
# born that way.
#
# 3
#
#
# RPT Phongkhin
#
# Thôi chào iem - CAM (cover)
#
# 3
#
#
# RPT Phongkhin
#
# Iem da ngu chua - nger (cover)
#
# 3
#
#
# RPT Phongkhin
#
# Marzuz,TSL - 2ndtime (pacman. rework)
#
# 3
#
#
# RPT Phongkhin
#
# im not sure how much I love you
#
# 3
#
#
# RPT Phongkhin
#
# rosé
#
# 3
#
#
# RPT Phongkhin
#
# minimix
#
# 3
#
#
# RPT Phongkhin
#
# she will be loved
#
# 3
#
#
# RPT Phongkhin
#
# dear Santa,i just want to be happy
#
# 3
#
#
# RPT Phongkhin
#
# hư quá đi
#
# 3
#
#
# RPT Phongkhin
#
# em zero the
#
# 3
#
#
# RPT Phongkhin
#
# here n now
#
# 3
#
#
# RPT Phongkhin
#
# good,bye
#
# 3
#
#
# RPT Phongkhin
#
# a little bit of your love
#
# 3
#
#
# RPT Phongkhin
#
# your girl(s)
#
# 3
#
#
# RPT Phongkhin
#
# sleepless ‘
#
# 3
#
#
# RPT Phongkhin
#
# lovestory ?
#
# 3
#
#
# RPT Phongkhin
#
# promise me/
#
# 3
#
#
# RPT Phongkhin
#
# minhmeo - Safe flight ( pacman. Edit )
#
# 3
#
#
# RPT Phongkhin
#
# Rhymastic - Treasure & Yêu 5 (pacman. Flip)
#
# 3
#
#
# RPT Phongkhin
#
# <ta hat cho nang
#
# 3
#
#
# RPT Phongkhin
#
# Hello (foolish) [feat. nân & TSL & pacman. redo]
#
# 3
#
#
# RPT Phongkhin
#
# JustaTee - Đã Lỡ Yêu Em Nhiều (pacmix & unmastered)
#
# 3
#
#
# RPT Phongkhin
#
# heart or hurt
#
# 3
#
#
# RPT Phongkhin
#
# Twinkly Tus - LALALA (pacman. flip)
#
# 3
#
#
# RPT Phongkhin
#
# <binh yen la luc long khong sau khong vui
#
# 3
#
#
# RPT Phongkhin
#
# @#$!%^#%!$
#
# 3
#
#
# RPT Phongkhin
#
# Safe flight - minhmeo.pacman flip.
#
# 3
#
#
# RPT Phongkhin
#
# Alt + F4
#
# 3
# Cofm ♫
#
# Mashup | Ai Chờ Ai - FloD ft. M! & Godthic
#
# 3
#
#
# Cofm ♫
#
# NGƯỜI ẤY (MASHUP BY COFM)
#
# 3
#
#
# Cofm ♫
#
# SOOBIN - THÁNG NĂM (SPECIAL VERSION) FT. SLIM V
#
# 3
#
#
# Cofm ♫
#
# #TAN4GAL - Mixtape Deep G Việt | Give Me Your Love
#
# 3
#
#
# Cofm ♫
#
# Mashup | Ngôi nhà hoa hồng... mỗi người nột nơi
#
# 2
#
#
# Cofm ♫
#
# (Full) Bất Lực - Nguyễn Trọng Tài (Edit)
#
# 3
#
#
# Cofm ♫
#
# Sau Tất Cả - cover by Loan Nguyen
#
# 3
#
#
# Cofm ♫
#
# Em chưa giấu anh điều gì (Audio edit) - D.Blue x Đạt G
#
# 3
#
#
# Cofm ♫
#
# CLME (Tử tế version) - Hoàng Tôn x Andree
#
# 3
#
#
# Cofm ♫
#
# Trời ơiiii đi tìm em cây bị rơi từ tầng 4 xuống...
#
# 2
#
#
# Cofm ♫
#
# Đừng nói tôi điên (version 2) - Hiền Hồ
#
# 2
#
#
# Cofm ♫
#
# Ai đưa em về nếu một ngày chúng ta không còn gặp (Mashup)
#
# 3
#
#
# Cofm ♫
#
# [Audio edit] Ngày mai nắng lên anh sẽ về 2019
#
# 3
#
#
# Cofm ♫
#
# Giấc Mơ (Angel Version)- Yanbi ft. Bùi Anh Tuấn
#
# 3
#
#
# Cofm ♫
#
# Nếu yêu anh thì đừng đi với ai kia
#
# 2
#
#
# Cofm ♫
#
# CHẮC ANH ĐANG - TIÊN TIÊN & TRANG ( COFM MASHUP )
#
# 2
#
#
# Cofm ♫
#
# Đã Lỡ Yêu Em Nhiều (Chill version)
#
# 2
#
#
# Cofm ♫
#
# 25 - Táo x YoungH x Sol'Bass x Nah x Chú 13 x Khói
#
# 2
#
#
# Cofm ♫
#
# KỂ TỪ ẤY (NOBODY LIKE YOU) - JUN PHẠM
#
# 2
#
#
# Cofm ♫
#
# Phía Sau Một Cô Gái (Remix) - Soobin Hoàng Sơn
#
# 3
#
#
# Cofm ♫
#
# Let Me Feel Your Love Tonight In Wonderland (Mashup)
#
# 2
#
#
# Cofm ♫
#
# Người Và Ta (Happy Ver inst)
#
# 2
#
#
# Cofm ♫
#
# Michael Constantino - Hit Song 2000*2016 Mashup
#
# 3
#
#
# Cofm ♫
#
# Demo Rnb 2016 - JustaTee ft. BigDaddy
#
# 3
#
#
# Cofm ♫
#
# BEAT - Người và Ta (R&B Ver Edited)
#
# 2
#
#
# Cofm ♫
#
# I'll Be There - JustaTee ft. Phương Ly (Leak)
#
# 3
#
#
# Cofm ♫
#
# Love yourself (R&B Version) - Edward Nguyen cover
#
# 3
#
#
# Cofm ♫
#
# Because I'm Stupid - SS501 ft.  Noo Phước Thịnh & Minh Quân
#
# 2
#
#
# Cofm ♫
#
# Acoustic - Because I'm Stupid - Fan Instrumental Cover
#
# 3
#
#
# Cofm ♫
#
# Stevie Hoang - Somebody's Girl (new song 2015)
#
# 3
#
#
# Cofm ♫
#
# Please - Kim Hyun Joong
#
# 2
#
#
# Cofm ♫
#
# Ryan Leslie - Diamond Girl (Sweet Version remix by Rhymastic)
#
# 2
#
#
# Hawys.
#
# tlinh - GÁI ĐỘC THÂN (HAWYS REMIX)
#
# 2
#
#
# Hawys.
#
# vô tình ta lạc mất nhau..
#
# 3
#
#
# Hawys.
#
# Chợt Tỉnh Giấc - Quang Anh Rhyder (Lo-fi ver by Hawys)
#
# 2
#
#
# Hawys.
#
# HIEUTHUHAI - NGHE NHƯ TÌNH YÊU (FELIKS ALVIN REMIX) | HAWYS EDIT
#
# 3
#
#
# Hawys.
#
# Moonlight Romance (Lo-fi Edit)
#
# 3
#
#
# Hawys.
#
# Da LAB - THỨC GIẤC (HAWYS REMIX)
#
# 3
#
#
# Hawys.
#
# HOÀNG TÔN x LYHAN - TÌNH YÊU NGỦ QUÊN (HAWYS 80s REMIX)
#
# 3
#
#
# Hawys.
#
# JSOL x Hoàng Duyên - Sài Gòn Hôm Nay Mưa (Lo-fi ver by Hawys)
#
# 3
#
#
# Hawys.
#
# Orange x Hoàng Dũng - Khi Em Lớn (Lo-fi ver by Hawys)
#
# 3
#
#
# Hawys.
#
# đơn phương là gì em nhỉ?
#
# 3
#
#
# Hawys.
#
# SƠN TÙNG M-TP | MUỘN RỒI MÀ SAO CÒN (HAWYS REMIX)
#
# 3
#
#
# Hawys.
#
# Anh có bàn tay để nắm tất cả nhưng không thế nắm được tay em..
#
# 3
#
#
# Hawys.
#
# 𝙪 𝙖𝙧𝙚 𝙖𝙡𝙡 𝙞 𝙩𝙝𝙞𝙣𝙠 𝙖𝙗𝙤𝙪𝙩 𝙖𝙩 𝙣𝙞𝙜𝙝𝙩..
#
# 3
#
#
# Hawys.
#
# lovesick 1402
#
# 2
#
#
# Hawys.
#
# Anh chỉ muốn anh gần em hơn..
#
# 3
#
#
# Hawys.
#
# có công mài sắt, có ngày iu em
#
# 3
#
#
# Hawys.
#
# vì con tim chưa bao giờ nghe theo lí trí..
#
# 2
#
#
# Hawys.
#
# Bozitt - Những gì anh nói (Lofi ver by Hawys)
#
# 3
#
#
# Hawys.
#
# L.Y.2
#
# 3
#
#
# Hawys.
#
# Xe Đạp - Charles Huynh Cover (Lo-fi ver by Hawys)
#
# 3
#
#
# Hawys.
#
# need u
#
# 3
#
#
# Hawys.
#
# hawys - sunrise
#
# 3
#
#
# Hawys.
#
# p l a y  d a t e (Lofi edit)
#
# 3
#
#
# Hawys.
#
# JUSTATEE x TIÊN TIÊN - CẦN GÌ HƠN (HAWYS X NGHIANGUYEN. REMIX)
#
# 3
#
#
# Hawys.
#
# PHÁO X WACK - HAI PHÚT HƠN (HAWYS REMIX)
#
# 3
#
#
# Hawys.
#
# Vẫn là QuaBanh nhưng..
#
# 3
#
#
# Hawys.
#
# Anh cho em mùa xuân (Lo-fi ver by Hawys)
#
# 3
#
#
# Hawys.
#
# 𝘔𝘦𝘮𝘰𝘳𝘪𝘦𝘴.. (Free Lo-Fi Type Beat)
#
# 3
#
#
# Hawys.
#
# đã lỡ iu em nhìu (hawys retro rimex)
#
# 3
#
#
# Hawys.
#
# Thắc Mắc (Lo-fi ver by Hawys) - Có lẽ em đã khóc rất nhiều..
#
# 3
#
#
# Hawys.
#
# Ｒｅａｌ ｆｒｉｅｎｄｓ(lofi ver by hawys)
#
# 3
#
#
# Hawys.
#
# HOAPROX ft XESI - NOI EM MUON TOI (HAWYS REMIX)
#
# 3
#
#
# Hawys.
#
# HAWYS - SEE THE LIGHT (FREE DOWNLOAD!)
#
# 3
#
#
# Hawys.
#
# Việt - Hơn Cả Mây Trời (lofi ver by hawys)
#
# 3
#
#
# Hawys.
#
# Thịnh Suy - Một đêm say (lo-fi ver by hawys)
#
# 3
#
#
# Hawys.
#
# 𝙚𝙢 𝙣𝙝𝙪 𝙗𝙤𝙣𝙜 𝙝𝙤𝙖
#
# 3
#
#
# Hawys.
#
# Maroon5 - Girls Like You (Hawys Remix)
#
# 3
#
#
# ShenlongZ
#
# SQUID GAME - ShenlongZ ReFlip (The Big Girl Doll ver.)
#
# 3
#
#
# ShenlongZ
#
# Thief Your Handsup - ShenlongZ X Arkins X DEMIXL
#
# 3
#
#
# ShenlongZ
#
# Thich Em Hoi Nhieu - WREN EVANS (ShenlongZ X Dnoise Remix)(Extended Mix)
#
# 3
#
#
# ShenlongZ
#
# SHENLONGZ - Infection Mixset 2021
#
# 3
#
#
# ShenlongZ
#
# DALAB - Thuc Giac (ShenlongZ Remix) Remix Contest
#
# 3
#
#
# ShenlongZ
#
# SANG XIN MIN - GILL & Kewtiie (ShenlongZ RMX)
#
# 3
#
#
# ShenlongZ
#
# Utilmate PACK ShenlongZ - The HOUSE (buy for Contact)
#
# 3
#
#
# ShenlongZ
#
# Muon Roi Ma Sao Con - Son Tung M-TP (ShenlongZ x NIX Remix)Clean Ver.
#
# 3
#
#
# ShenlongZ
#
# Kulikata - ShenlongZ f.t KiSu (Original Mix) (Extended)
#
# 3
#
#
# ShenlongZ
#
# ShenlongZ - LIKE DROP LIKE THAT (Extended Mix)
#
# 3
#
#
# ShenlongZ
#
# PHONE - ShenlongZ X TPA (Original Mix)
#
# 3
#
#
# ShenlongZ
#
# i'm R$ch - ShenlongZ ft. TYTY (Original Mix)
#
# 3
#
#
# ShenlongZ
#
# ShenlongZ - Ookay (Extended Mix)
#
# 3
#
#
# ShenlongZ
#
# SHENLONGZ ft. DNOISE - CHẲNG MUỐN VỀ NHÀ (Orignal Mix) | Don't Wanna Go Home
#
# 3
#
#
# ShenlongZ
#
# Wish A Treasure (ShenlongZ Mashup)
#
# 3
#
#
# Kimmese
#
# Kimmese X Triple D - Triệu Ngọn Lửa Một Khát Vọng
#
# 3
#
#
# Kimmese
#
# Kimmese - Ngoi Nha Xanh Official  Audio
#
# 3
#
#
# Kimmese
#
# Kimmese - YSW Official Audio +Lyric
#
# 3
#
#
# Kimmese
#
# ITSABET  (REMIX CONTEST - JUSTIN TECHN9)
#
# 3
#
#
# Kimmese
#
# ISABET (REMIX CONTEST - PHAN HOANG MINH a.ka W n C)
#
# 3
#
#
# Kimmese
#
# ISABET - (REMIX CONTEST - D.Baola X Lupin)
#
# 3
#
#
# Kimmese
#
# ITSABET (REMIX CONTEST - FUNNYBAT)
#
# 3
#
#
# Kimmese
#
# ITSABET (REMIX CONTEST - Max Benderz)
#
# 3
#
#
# Kimmese
#
# ITSABET ft Andree Right Hand
#
# 3
#
#
# Kimmese
#
# The very first of Loving You Demo a.ka.  Kim Sieu Quan 2
#
# 3
#
#
# Kimmese
#
# Liltle cover song from The Weeknd
#
# 3
#
#
# Kimmese
#
# Loving You Sunny - Kimmese Ft Đen ( Prod.by Touliver & JustaTee )
#
# 3
#
#
# Kimmese
#
# Kimmese - Ngỡ Đâu Tình Đã Quên Mình ( Prod. by Touliver )
#
# 3
#
#
# Kimmese
#
# Love Lung Linh
#
# 3
#
#
# Kimmese
#
# Kimmese  - Green Eyes
#
# 3
#
#
# Kimmese
#
# Make Love To Me
#
# 3
#
#
# Kimmese
#
# Kimmese - Co Nguoi Nghi
#
# 3
#
#
# Kimmese
#
# Kimmese - Emotions ( Karaoke version )
#
# 3
#
#
# Kimmese
#
# Juss Juss Juss ( Khuyên nên dùng cho nhạc chuông, nhạc chờ
#
# 3
#
#
# Kimmese
#
# Kimmese - Your girl is a ho
#
# 3
#
#
# Kimmese
#
# Say goodbye
#
# 3
#
#
# Kimmese
#
# Kimmese ft Antoneus Maximus - Emotions ( Official Audio )
#
# 3
#
#
# Kimmese
#
# BREEZY WIND - CLAYTON FT KIMMESE
#
# 3
#
#
# Kimmese
#
# Kimmese - Someone like you Remix
#
# 3
#
#
# Kimmese
#
# Kimmese - Strong ( English version)
#
# 3
#
#
# Kimmese
#
# Kimmese - Strong
#
# 3
#
#
# Kimmese
#
# Kimmese ft JustaTee - Real Love ( Acoustic version ) Prod. by Touliver
#
# 3
#
#
# Kimmese
#
# Kimmese - Leave Me Prod. by Vagno
#
# 3
#
#
# Kimmese
#
# Feel the beat demo 2 ( Prod. by Touliver )
#
# 3
#
#
# Kimmese
#
# Kimmese - Feel the beat ( demo ) Prod. by Touliver
#
# 3
#
#
# Kimmese
#
# Kimmese-Sunny
#
# 3
#
#
# Kimmese
#
# Kimmese -  U A Jerk Remix (High Quality)
#
# 3
#
#
# Kimmese
#
# Kimmese - Cong tu bot
#
# 3
#
#
# Kimmese
#
# Sex ( 17 YEARS OLD )
#
# 3
#
#
# Kimmese
#
# Crunk it mix1
#
# 2
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝙽𝚘𝚒 𝚝𝚊 𝚌𝚑𝚘 𝚎𝚖_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 2
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚃𝚊𝚢 𝚗𝚊𝚖 𝚝𝚊𝚢 𝚛𝚘𝚒_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 2
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝙽𝚎𝚞 𝚊𝚗𝚑 𝚝𝚑𝚊𝚢 𝚕𝚘𝚗𝚐 𝚖𝚒𝚗𝚑 𝚢𝚎𝚞 𝚍𝚞𝚘𝚒_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝙻𝚘𝚒 𝚝𝚊𝚒 𝚊𝚗𝚑_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝙳𝚒 𝚗𝚐𝚊𝚗𝚐 𝚗𝚐𝚊𝚢 𝚋𝚞𝚘𝚗_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝙽𝚐𝚞𝚘𝚒 𝚕𝚊 𝚝𝚑𝚘𝚊𝚗𝚐 𝚚𝚞𝚊_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝙷𝚊𝚗𝚑 𝚙𝚑𝚞𝚌 𝚋𝚘 𝚛𝚘𝚒 𝚎𝚖_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝙽𝚊𝚖 𝚊𝚢_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝙽𝚊𝚗𝚐 𝚊𝚖 𝚡𝚊 𝚍𝚊𝚗_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝙷𝚊𝚗𝚑 𝚙𝚑𝚞𝚌 𝚖𝚘𝚒_𝚂𝚘𝚗 𝚃𝚞𝚗𝚐 𝙼𝚃𝙿 (𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋)
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝙲𝚑𝚊𝚌 𝚊𝚒 𝚍𝚘 𝚜𝚎 𝚟𝚎_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 3107/3_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚈𝚎𝚞 𝚝𝚑𝚞𝚘𝚗𝚐 𝚗𝚐𝚊𝚢 𝚍𝚘_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 3107_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝙷𝚊𝚙𝚙𝚢 𝚏𝚘𝚛 𝚞_𝚅𝚞 (𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋)
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚈𝚎𝚞 5_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚑𝚎𝚝 𝚝𝚑𝚞𝚘𝚗𝚐 𝚌𝚊𝚗 𝚗𝚑𝚘_𝙳𝚞𝚌 𝙿𝚑𝚞𝚌 (𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋)
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚃𝚑𝚊𝚗𝚐 𝚍𝚒𝚎𝚗_𝙹𝚞𝚜𝚝𝚊𝚃𝚎𝚎 (𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋)
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝙲𝚘 𝚗𝚑𝚞 𝚔𝚑𝚘𝚗𝚐 𝚌𝚘_𝙷𝚒𝚎𝚗 𝙷𝚘 (𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋)
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚌𝚑𝚊𝚖 𝚔𝚑𝚎 𝚝𝚒𝚖 𝚊𝚗𝚑 𝚖𝚘𝚝 𝚌𝚑𝚞𝚝 𝚝𝚑𝚘𝚒_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚊𝚗𝚑 𝚖𝚞𝚘𝚗 𝚗𝚐𝚑𝚎 𝚐𝚒𝚘𝚗𝚐 𝚎𝚖 𝚗𝚘𝚒_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚊𝚗𝚑 𝚝𝚊 𝚋𝚘 𝚎𝚖 𝚛𝚘𝚒_𝙷𝚞𝚘𝚗𝚐 𝙶𝚒𝚊𝚗𝚐 (𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋)
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚔𝚑𝚘𝚗𝚐 𝚝𝚑𝚎 𝚌𝚞𝚗𝚐 𝚗𝚑𝚊𝚞 𝚜𝚞𝚘𝚝 𝚔𝚒𝚎𝚙_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚊𝚗𝚑 𝚌𝚑𝚒𝚎𝚞 𝚝𝚊𝚗_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚌𝚘 𝚝𝚊𝚝 𝚌𝚊 𝚗𝚑𝚞𝚗𝚐 𝚝𝚑𝚒𝚎𝚞 𝚊𝚗𝚑_𝙴𝚛𝚒𝚔 (𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋)
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝙰𝚗𝚑 𝚍𝚊 𝚚𝚞𝚎𝚗 𝚟𝚘𝚒 𝚌𝚘 𝚍𝚘𝚗_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚝𝚒𝚗𝚑 𝚍𝚎𝚙 𝚍𝚎𝚗 𝚖𝚊𝚢 𝚌𝚞𝚗𝚐 𝚝𝚊𝚗_𝚅𝚒𝚎𝚝 (𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋)
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚗𝚐𝚊𝚢 𝚋𝚎𝚗 𝚎𝚖_𝚆𝚞𝚢𝚗 (𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋)
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚗𝚐𝚞𝚘𝚒 𝚖𝚒𝚗𝚑 𝚢𝚎𝚞 𝚌𝚑𝚞𝚊 𝚌𝚑𝚊𝚌 𝚍𝚊 𝚢𝚎𝚞 𝚖𝚒𝚗𝚑_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚊𝚖 𝚝𝚑𝚊𝚖 𝚋𝚎𝚗 𝚎𝚖_𝚂𝚘𝚗 𝚃𝚞𝚗𝚐 𝙼𝚃𝙿 (𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋)
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚃𝚊 𝚌𝚘𝚗 𝚢𝚎𝚞 𝚗𝚑𝚊𝚞_𝙳𝚞𝚌 𝙿𝚑𝚞𝚌 (𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋)
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚝𝚑𝚊𝚗𝚐 𝚗𝚊𝚖_𝚜𝚘𝚘𝚋𝚒𝚗 (𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋)
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚑𝚘𝚗 𝚌𝚊 𝚖𝚊𝚢 𝚝𝚛𝚘𝚒_𝚅𝚒𝚎𝚝 (𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋)
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚝𝚛𝚘 𝚍𝚞𝚊_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚎𝚖 𝚕𝚊 𝚋𝚊 𝚗𝚘𝚒 𝚌𝚞𝚊 𝚊𝚗𝚑_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
#
#
# 𝚒 𝚑𝚊𝚟𝚎 𝚊 𝚜𝚕𝚘𝚠𝚎𝚍 𝚜𝚘𝚗𝚐
#
# 𝚂𝚊𝚒 𝙶𝚘𝚗 𝚑𝚘𝚖 𝚗𝚊𝚢 𝚖𝚞𝚊_𝚜𝚕𝚘𝚠𝚎𝚍+𝚛𝚎𝚟𝚎𝚛𝚋
#
# 3
# TaylorDaClownn.
#
# Nhiều hơn một câu. (Prod. GokuBeats)
#
# 3
#
#
# TaylorDaClownn.
#
# Taylor x Vũ Cát Tường | Tìm Hành Tinh Khác (Rap Ver.)
#
# 3
#
#
# TaylorDaClownn.
#
# Em Dou Thể Biết (Prod.GC)
#
# 3
#
#
# TaylorDaClownn.
#
# Buôn Hàng (R&B Guitar Remake) (Prod. Pdubcookin)
#
# 3
#
#
# TaylorDaClownn.
#
# Có me on the phone (Prod. Wavytrbl)
#
# 3
#
#
# TaylorDaClownn.
#
# Airdrop (Prod. Kiyoto)
#
# 3
#
#
# TaylorDaClownn.
#
# Một Ngày Để ILL(Prod. Vincent 88)
#
# 3
#
#
# TaylorDaClownn.
#
# Love more than SAY (Prod.GC)
#
# 3
#
#
# TaylorDaClownn.
#
# Heinekens for rainy days - Taylor x Kean (Prod. Flepy)
#
# 3
#
#
# TaylorDaClownn.
#
# It's you who took the smiles away.
#
# 3
#
#
# TaylorDaClownn.
#
# Messed Up Tonight(Prod. Pacific)
#
# 3
#
#
# TaylorDaClownn.
#
# Rollercoaster(Prod. Nammu.)
#
# 3
#
#
# TaylorDaClownn.
#
# Ready To Love (Prod.GC)
#
# 3
#
#
# TaylorDaClownn.
#
# Rolling Through My Mind - Taylor x KhgTrn (Prod. Vincent)
#
# 3
#
#
# TaylorDaClownn.
#
# 7 ELEVEN (Produced by GC)
#
# 3
#
#
# TaylorDaClownn.
#
# EVERYDAYxEVERYNIGHT 2.0 | Taylor x $GWang
#
# 3
#
#
# TaylorDaClownn.
#
# Anh co the nhan cho em mot tin khong?
#
# 3
#
#
# TaylorDaClownn.
#
# Aishiteru <33
#
# 3
#
#
# TaylorDaClownn.
#
# Cinderella
#
# 3
#
#
# TaylorDaClownn.
#
# G9 Barbie..
#
# 3
#
#
# TaylorDaClownn.
#
# Buoi sang cua em the nao?
#
# 3
#
#
# TaylorDaClownn.
#
# Hay 🍇 anh vao nhung ngay mua (Prod. lowna )
#
# 3
#
#
# TaylorDaClownn.
#
# Trai tim ngot ngao - ft. Flower Flow
#
# 3
#
#
# TaylorDaClownn.
#
# em la cuc nuoc da cua anh
#
# 3
#
#
# TaylorDaClownn.
#
# Tình đắng như câu chuyện cụa ziêng mình - Taylor x Ne
#
# 3
#
#
# TaylorDaClownn.
#
# lonely christmas :< (Prod. Lowna)
#
# 3
#
#
# TaylorDaClownn.
#
# BABEDONTLIE - Taylor X Mous
#
# 3
#
#
# 𝑪𝒂̀ 𝒑𝒉𝒆̂ 𝒔𝒖̛̃𝒂 (đá) ☕
#
# Gặp gỡ, Yêu đương và Được bên em | Phan Mạnh Quỳnh
#
# 3
#
#
# 𝑪𝒂̀ 𝒑𝒉𝒆̂ 𝒔𝒖̛̃𝒂 (đá) ☕
#
# Thức Giấc - Da LAB
#
# 3
#
#
# 𝑪𝒂̀ 𝒑𝒉𝒆̂ 𝒔𝒖̛̃𝒂 (đá) ☕
#
# Đường Tôi Chở Em Về  - Cukak Remix - Buitruonglinh
#
# 3
#
#
# 𝑪𝒂̀ 𝒑𝒉𝒆̂ 𝒔𝒖̛̃𝒂 (đá) ☕
#
# Thương Em Là Điều Anh Không Thể Ngờ (Lofi Ver.) - Noo Phước Thịnh x Freak D
#
# 3
#
#
# 𝑪𝒂̀ 𝒑𝒉𝒆̂ 𝒔𝒖̛̃𝒂 (đá) ☕
#
# ĐƯỜNG CHÂN TRỜI - CHILLIES
#
# 3
#
#
# 𝑪𝒂̀ 𝒑𝒉𝒆̂ 𝒔𝒖̛̃𝒂 (đá) ☕
#
# Đường Tôi Chở Em Về( Lofi Ver) -  Buitruonglinh X Freak D
#
# 3
#
#
# 𝑪𝒂̀ 𝒑𝒉𝒆̂ 𝒔𝒖̛̃𝒂 (đá) ☕
#
# Mộng Du - Chillies
#
# 3
#
#
# 𝑪𝒂̀ 𝒑𝒉𝒆̂ 𝒔𝒖̛̃𝒂 (đá) ☕
#
# Một Cái Tên - Chillies x Orange
#
# 3
#
#
# 𝑪𝒂̀ 𝒑𝒉𝒆̂ 𝒔𝒖̛̃𝒂 (đá) ☕
#
# Ms. May - Chillies ft. Magazine
#
# 3
#
#
# 𝑪𝒂̀ 𝒑𝒉𝒆̂ 𝒔𝒖̛̃𝒂 (đá) ☕
#
# KHI EM LỚN - FREXS REMIX HOT TIKTOK  -Orange X Hoàng Dũng  EM SẼ NGÃ ĐAU HƠN BÂY GIỜ
#
# 2
#
#
# 𝑪𝒂̀ 𝒑𝒉𝒆̂ 𝒔𝒖̛̃𝒂 (đá) ☕
#
# Bao Nhiêu - Chillies
#
# 3
#
#
# 𝑪𝒂̀ 𝒑𝒉𝒆̂ 𝒔𝒖̛̃𝒂 (đá) ☕
#
# - GỬI VỢ TƯƠNG LAI LOFI- KayDee Ft Long Nón Lá
#
# 3
#
#
# 𝑪𝒂̀ 𝒑𝒉𝒆̂ 𝒔𝒖̛̃𝒂 (đá) ☕
#
# Noo Phước Thịnh COVER “Chạm khẽ tim anh một chút thôi” LIVE @ Mây In The Nest Đà Lạt
#
# 3
#
#
# 𝑪𝒂̀ 𝒑𝒉𝒆̂ 𝒔𝒖̛̃𝒂 (đá) ☕
#
# NẾU GỌI LÀ ANH EM REMIX -  THIÊN DŨNG
#
# 2
#
#
# Rapital
#
# Rapitalove EP| Tay To - RPT MCK x RPT PhongKhin (Prod. by RPT PhongKhin)
#
# 3
#
#
# Rapital
#
# Rapitalove EP | SUGAR - RPT JasonDilla x RPT Orijinn (prod. Leonn & RPT LT)
#
# 3
#
#
# Rapital
#
# Rapitalove EP | ĐÊM TRONG VEO - RPT Groovie x RPT Gonzo (Prod. Fat_benn)
#
# 3
#
#
# Rapital
#
# Rapitalove EP | U ME - RPT TC x RPT Duke (prod. by RPT Phongkhin)
#
# 3
#
#
# Rapital
#
# Rapitalove EP | XTC - RPT Groovie x RPT Orijinn x RPT JasonDilla (Prod. by Derkalavier)
#
# 3
#
#
# Rapital
#
# 1 SAO (#HNDCMM part 2) - RPT Jasondilla (Official Audio)
#
# 3
#
#
# Rapital
#
# Rap Chậm Thôi (#HNDCMM) - RPT MCK x RPT Orijinn ft. RZ Ma$ (Official Audio)
#
# 3
#
#
# Rapital
#
# RAPITALITY (Prod. by Derkalavier)
#
# 3
#
#
# Rapital
#
# Cái Giá 2 - JASON x LAKE
#
# 3
#
#
# Rapital
#
# Tâm sự - LAKE x JASON
#
# 3
#
#
# Rapital
#
# Tự Sát - Ngơ x Lộc x JASON (Prod. by Nclownz)
#
# 3
#
#
# Rapital
#
# nếu mày cũng như tao - GONZO x Jinn
#
# 3
#
#
# Rapital
#
# cuối ngày - JASON x Groovie x GONZO
#
# 3
#
#
# Rapital
#
# Thủ Đô - Groovie  x JASON x ?
#
# 3
#
#
# Rapital
#
# Cái Giá - JASON x 8T
#
# 3
#
#
# Rapital
#
# Nếu Như - JASON
#
# 3
#
#
# Rapital
#
# vài phút - JASON x Groovie x GONZO
#
# 3
#
#
# Rapital
#
# THẾ GIỚI NÀY - JASON
#
# 3
#
#
# Vu Ngan My
#
# Easy On Me - Adele | Cover by Vũ Ngân Mỹ
#
# 2
#
#
# Vu Ngan My
#
# Wildest Dreams - Taylor Swift | Acapella Cover
#
# 3
#
#
# Vu Ngan My
#
# 3107 3 và 1 không 2 | W/n x Nâu x Duongg x Titie | Cover by Vũ Ngân Mỹ
#
# 3
#
#
# Vu Ngan My
#
# Lần Hẹn Hò Đầu Tiên + Phố Đã Lên Đèn - Huyền Tâm Môn | Lo-Fi nhà làm
#
# 3
#
#
# Vu Ngan My
#
# Gone - Rose | Cover by Vũ Ngân Mỹ
#
# 3
#
#
# Vu Ngan My
#
# Happy For You - Lukas Graham | Acapella cover
#
# 3
#
#
# Vu Ngan My
#
# Đại Lộ Đông Tây - Uyên Linh | Vũ Ngân Mỹ cover
#
# 3
#
#
# Vu Ngan My
#
# SG đau nhòng qué
#
# 3
#
#
# Vu Ngan My
#
# Billie Eilish - Wish You Were Gay || Cover
#
# 3
#
#
# Vu Ngan My
#
# Lana Del Rey - Love || Cover (Zone FM 102.7mhz)
#
# 3
#
#
# Vu Ngan My
#
# [STUDIO] LOVE - Lana del Rey
#
# 2
#
#
# Vu Ngan My
#
# Easy On Me - Adele | Cover by Vũ Ngân Mỹ
#
# 2
#
#
# Vu Ngan My
#
# Wildest Dreams - Taylor Swift | Acapella Cover
#
# 3
#
#
# Vu Ngan My
#
# 3107 3 và 1 không 2 | W/n x Nâu x Duongg x Titie | Cover by Vũ Ngân Mỹ
#
# 3
#
#
# Vu Ngan My
#
# Lần Hẹn Hò Đầu Tiên + Phố Đã Lên Đèn - Huyền Tâm Môn | Lo-Fi nhà làm
#
# 3
#
#
# Vu Ngan My
#
# Gone - Rose | Cover by Vũ Ngân Mỹ
#
# 3
#
#
# Vu Ngan My
#
# Happy For You - Lukas Graham | Acapella cover
#
# 3
#
#
# Vu Ngan My
#
# Đại Lộ Đông Tây - Uyên Linh | Vũ Ngân Mỹ cover
#
# 3
#
#
# Vu Ngan My
#
# SG đau nhòng qué
#
# 3
#
#
# Vu Ngan My
#
# Billie Eilish - Wish You Were Gay || Cover
#
# 3
#
#
# Vu Ngan My
#
# Lana Del Rey - Love || Cover (Zone FM 102.7mhz)
#
# 3
#
#
# Vu Ngan My
#
# [STUDIO] LOVE - Lana del Rey
#
# 2
#
#
# Touliver
#
# BIGCITYBOI
#
# 3
#
#
# Touliver
#
# IN DA MORNING
#
# 3
#
#
# Touliver
#
# BInz - Thôi Anh Không Chơi [ Touliver Remix ]
#
# 3
#
#
# Touliver
#
# NÓI ĐIÊU LÀM CHÓ
#
# 3
#
#
# Touliver
#
# DUSTED ( Feat. Mr.A , DUSTEE )
#
# 3
#
#
# Touliver
#
# EM KHONG THE [ INSTRUMENTAL ]
#
# 3
#
#
# Touliver
#
# EM KHONG THE
#
# 3
#
#
# Touliver
#
# Rhymastic - NENVAHOA ( TLVR RMX )
#
# 3
#
#
# Touliver
#
# CATENA ( INSTRU )
#
# 3
#
#
# Touliver
#
# GOML
#
# 3
#
#
# Touliver
#
# EM OI CU VUI ( ORIGINAL )
#
# 3
#
#
# Touliver
#
# RHYMASTIC - KHI MAN HINH TAT ( TLVR RMX )
#
# 3
#
#
# Touliver
#
# TOULIVER X DJ GIN - GINTONIC
#
# 3
#
#
# Touliver
#
# I KNOW ( TLVR RMX )
#
# 3
#
#
# Touliver
#
# ILABYOU ( TLVR RMX )
#
# 3
#
#
# Touliver
#
# LOVINU
#
# 3
#
#
# Touliver
#
# COAICHO
#
# 3
#
#
# Touliver
#
# demo rhymastic 2018
#
# 3
#
#
# Touliver
#
# Dont worry
#
# 3
#
#
# Touliver
#
# Di Ve Dau
#
# 3
#
#
# Touliver
#
# 1DEE X F - CON GAI 2016
#
# 3
#
#
# Touliver
#
# 1LIKE
#
# 3
#
#
# Touliver
#
# HOTPOT
#
# 3
#
#
# Touliver
#
# GHOSTLY
#
# 3
#
#
# Touliver
#
# Tra My Idol - LMFYLTN
#
# 3
#
#
# Touliver
#
# TINLE - DA YEU EM NHIEU ( TLVR RMX )
#
# 3
#
#
# Touliver
#
# LALALA [ Instrumental ]
#
# 3
#
#
# Touliver
#
# BIGDADDY - CHECK OUT DA BASS ( TLVR RMX )
#
# 3
#
#
# Touliver
#
# Toc Tien - I'm In Love
#
# 3
#
#
# Touliver
#
# Vmix
#
# 3
#
#
# Touliver
#
# NOI SAU DEM VANG
#
# 3
#
#
# Touliver
#
# VI TOI CON SONG ( TLVR RMX )
#
# 3
#
#
# Touliver
#
# PUT YOUR HANDS UP ( TLVR RMX )
#
# 3
#
#
# Touliver
#
# Khong The Tim Lai Binh Yen
#
# 3
#
#
# Touliver
#
# #IDFWU
#
# 3
#
#
# Touliver
#
# PARADISE
#
# 3
#
#
# Touliver
#
# ISAAC - MR RIGHT ( TLVR RMX )
#
# 3
#
#
# Touliver
#
# SPACESPEAKERS & FRIENDS - ME YEU
#
# 3
#
#
# Touliver
#
# SS BEAST
#
# 3
#
#
# Touliver
#
# Sacota ( ft BigDaddy )
#
# 3
#
#
# Touliver
#
# EM DEP NHAT DEM NAY ( Touliver Remix )
#
# 3
#
#
# Touliver
#
# Team V & NSUT Thanh Loc - Da Co Hoai Lang
#
# 3
#
#
# Touliver
#
# DAYDREAMS
#
# 3
#
#
# Touliver
#
# Angel / Faded
#
# 3
#
#
# Touliver
#
# Hoa Co Mua Xuan
#
# 3
#
#
# Touliver
#
# Ngay Mai ( Touliver Remix )
#
# 3
#
#
# Touliver
#
# Suboi X Touliver - Tro Choi
#
# 3
#
#
# Touliver
#
# Em Về Tinh Khôi 2015
#
# 3
#
#
# Touliver
#
# MEV
#
# 3
#
#
# Touliver
#
# DLNDTD ( TLVR RMX )
#
# 3
#
#
# Touliver
#
# Mlee - I CAN DO
#
# 3
#
#
# Touliver
#
# The Rasmus - IN THE SHADOWS ( TLVR REMIX )
#
# 3
#
#
# Touliver
#
# MNDNG ( ft SHU X MR.A )
#
# 3
#
#
# Touliver
#
# Make You Smile
#
# 3
#
#
# Touliver
#
# Zedd ft Hayley Williams - Stay The Night ( Touliver Remix )
#
# 3
#
#
# Touliver
#
# Rhymastic ft CuongSeven & Shu - Summertime
#
# 3
#
#
# Touliver
#
# OUR*LOVE
#
# 3
#
#
# Touliver
#
# Nhật Thu - Em & Đêm
#
# 3
#
#
# Touliver
#
# Mr.A - TELL ME WHY  ( 55 REMIX )
#
# 3
#
#
# Touliver
#
# Bâng Khuâng ( ft JustaTee )
#
# 3
#
#
# Touliver
#
# T.E.A.R
#
# 3
#
#
# Touliver
#
# Trà My idol - Tóc Ngắn Môi Xinh ( Original )
#
# 3
#
#
# Touliver
#
# Think About Her
#
# 3
#
#
# Touliver
#
# Lungtalungtung
#
# 3
#
#
# Touliver
#
# Andree Right Hand ft. Rhymastic - DCME
#
# 3
#
#
# Touliver
#
# Live Your Life
#
# 3
#
#
# Touliver
#
# Love is not easy
#
# 3
#
#
# Touliver
#
# Faded ( Touliver Dubstep Mix )
#
# 3
#
#
# Touliver
#
# Faraway
#
# 3
#
#
# Touliver
#
# Far Away
#
# 3
#
#
# Touliver
#
# Kimmese - Last Xmas
#
# 3
#
#
# Touliver
#
# Bad Boys ( Ft Binz )
#
# 3
#
#
# Touliver
#
# Quiks ( Ft LK , Rhymastic , Kimmese )
#
# 3
#
#
# Touliver
#
# Big Sean - Beware ( Touliver Remix )
#
# 3
#
#
# Touliver
#
# Hoa Sữa 2013 ( Ft Kimmese , Mr.A , JustaTee )
#
# 3
#
#
# Touliver
#
# Triple D ft Rhymastic , Binz - Đây Là Việt Nam ( Touliver Remix )
#
# 3
#
#
# Touliver
#
# Nhật Thu - Như Vậy Đi ( ft Mr.A )
#
# 3
#
#
# Touliver
#
# Last Time
#
# 3
#
#
# Touliver
#
# Binz ft Kimmese - Solitude
#
# 3
#
#
# Touliver
#
# Willowy
#
# 3
#
#
# Touliver
#
# How To Heal A Broken Heart
#
# 3
#
#
# Touliver
#
# Spaceboys - Bass Quake Teaser
#
# 3
#
#
# Touliver
#
# Faded ( Original )
#
# 3
#
#
# Touliver
#
# HATER ( Original Mix )
#
# 3
#
#
# Touliver
#
# Hopeless
#
# 3
#
#
# Touliver
#
# Block Block ( Original )
#
# 3
#
#
# Touliver
#
# Thôi Em Nhé
#
# 3
#
#
# Touliver
#
# JustaTee ft Kimmese - Loi Noi Doi Chan That ( Instrumental )
#
# 3
#
#
# Touliver
#
# JustaTee ft Kimmese - Loi Noi Doi Chan That
#
# 3
#
#
# Touliver
#
# Tôi cô đơn
#
# 3
#
#
# Touliver
#
# !llusion Love
#
# 3
#
#
# Touliver
#
# Lil' Knight & Touliver - Hanoi Hustle ( Original Mix )
#
# 3
#
#
# Touliver
#
# Dream Of A Lonely Man
#
# 3
#
#
# Touliver
#
# Love Sick
#
# 3
#
#
# Touliver
#
# J-Kwon - Tipsy ( Touliver Remix )
#
# 3
#
#
# Touliver
#
# The Day I Met You
#
# 3
#
#
# Touliver
#
# B2NSL
#
# 3
#
#
# Touliver
#
# DECYM
#
# 3
#
#
# Touliver
#
# JagerBomb ( Original Mix )
#
# 3
#
#
# Touliver
#
# Rapsoul - You Better Run ( Touliver Remix )
#
# 3
#
#
# Touliver
#
# Andree Right Hand - Wet Lens ( Touliver Deepmix )
#
# 3
#
#
# Touliver
#
# The love song
#
# 3
#
#
# Touliver
#
# AONENIGHTSTAND
#
# 3
#
#
# Touliver
#
# Lovely Day
#
# 3
#
#
# Touliver
#
# Kimmese - Hương Ngọc Lan ( Instrumental )
#
# 3
#
#
# Touliver
#
# Lil Knight ft JustaTee - Không tin sớm mai bình yên ( Touliver Remix )
#
# 3
#
#
# Touliver
#
# Sweetie Cake
#
# 3
#
#
# Touliver
#
# 365daBand - Get On The Floor ( Ai Đó Đêm Nay )
#
# 3
#
#
# Touliver
#
# Leggoo ( Original Mix )
#
# 3
#
#
# Touliver
#
# Bad Dreams ( Original Mix )
#
# 3
#
#
# Touliver
#
# Dont Stop ( Original Mix )
#
# 3
#
#
# Touliver
#
# Kimmese - Hương Ngọc Lan
#
# 3
#
#
# Touliver
#
# Sad Flow ( Original Mix )
#
# 3
#
#
# Touliver
#
# HeartBreak ( You're Not the Only One )
#
# 3
#
#
# Touliver
#
# G-Dragon - One Of A Kind ( Touliver Remix )
#
# 3
#
#
# Touliver
#
# Troll
#
# 3
#
#
# Touliver
#
# Under the Moon
#
# 3
#
#
# Touliver
#
# Andree Right Hand - B.A.S ( Touliver Remix )
#
# 3
#
#
# Touliver
#
# NO MORE TEARS TO CRY
#
# 3
#
#
# Touliver
#
# I'd Come for You
#
# 3
#
#
# Touliver
#
# Spontaneous
#
# 3
#
#
# Touliver
#
# Strained ( Original Mix )
#
# 3
#
#
# Touliver
#
# Don't Miss The Train
#
# 3
#
#
# Touliver
#
# Touliver & Rhymastic - Angry Boy ( Original Mix )
#
# 3
#
#
# Touliver
#
# Beautiful Girl ( Instrumental )
#
# 3
#
#
# Touliver
#
# Sick Of This love
#
# 3
#
#
# Touliver
#
# Party All Night
#
# 3
#
#
# Touliver
#
# Feel The Life ( Touliver Remix )
#
# 3
#
#
# Touliver
#
# Wowy - Khu Tao Sống ( Touliver Dirty Bass Mix )
#
# 3
#
#
# Touliver
#
# Unname
#
# 3
#
#
# Touliver
#
# She Neva Knows ( Piano Version )
#
# 3
#
#
# Touliver
#
# Andree Right Hand - Wet Lens
#
# 3
#
#
# Touliver
#
# Do You Remember
#
# 3
#
#
# Touliver
#
# Tell Me Why ( Touliver R&B Mix )
#
# 3
#
#
# Touliver
#
# Touliver ft Soobin - Oh oh ( Original Mix )
#
# 3
#
#
# Touliver
#
# Touliver ft JustaTee - Juss ( Good Morning VietNam )
#
# 3
#
#
# Touliver
#
# Trà My Idol - Vì sao anh không đến ( Touliver Mix )
#
# 3
#
#
# Touliver
#
# L.O.V.E ( ft JustaTee,Kimmese )
#
# 3
#
#
# Touliver
#
# Cycle
#
# 3
#
#
# Touliver
#
# ALX Kim Hoàng - Sunday Morning ( Touliver Mix )
#
# 3
#
#
# Touliver
#
# Cuongseven ft Mr.A - Beautiful Girl ( Original Mix )
#
# 3
#
#
# Touliver
#
# When the smile goes blue
#
# 3
#
#
# Touliver
#
# Minh Kiên - Vụt Bay
#
# 3
#
#
# Touliver
#
# Phương Vy feat. Antoneus Maximus - I'm La Vy ( Touliver Mix )
#
# 3
#
#
# Touliver
#
# Fuck Love ( Original Mix )
#
# 3
#
#
# Touliver
#
# Khi Em Ra Đi
#
# 3
#
#
# Touliver
#
# JustaTee - She Neva Knows ( Original )
#
# 3
#
#
# Touliver
#
# Fragrance
#
# 3
#
#
# Touliver
#
# Lưu Hương Giang - Your Game
#
# 3
#
#
# Touliver
#
# Yêu Em Vậy Thôi ( Touliver Remix )
#
# 3
#
#
# Touliver
#
# Hoa sữa ( Touliver Remix )
#
# 3
#
#
# Touliver
#
# MR.A - Tell Me Why ( Original )
#
# 3
#
#
# Touliver
#
# ...
#
# 2
#
#
# Nyctophilia
#
# Nghia - Saturday Sunset Podcast 1
#
# 3
#
#
# Nyctophilia
#
# HIME Sunset @ Studio Adventure 3.0 - 10/03/2018
#
# 3
#
#
# Nyctophilia
#
# Duca Dan - Nyctophilia Session #2
#
# 2
#
#
# Nyctophilia
#
# Viet Anh - Nyctophilia Session #3
#
# 3
#
#
# Nyctophilia
#
# Nghia - Gone
#
# 2
#
#
# Nyctophilia
#
# Tung Tim - Nyctophilia Session #4
#
# 2
#
#
# Nyctophilia
#
# Nghi - Nyctophilia Session #5
#
# 2
#
#
# Nyctophilia
#
# HIME - Debut Mix - Kobala #1
#
# 3
#
#
# Nyctophilia
#
# Duca Dan - Nyctophilia Session #6
#
# 2
#
#
# Nyctophilia
#
# My Nguyen - Nyctophilia Session #1
#
# 3
#
#
# Nyctophilia
#
# Tung Tim - Nyctophilia Session #8
#
# 3
#
#
# Nyctophilia
#
# Tung Tim - Mad Honey at Rafiki's Elephants Party
#
# 2
#
#
# Nyctophilia
#
# Tung Tim - Nyctophilia Session #16
#
# 2
#
#
# Nyctophilia
#
# Forest - Nyctophilia Session #9
#
# 2
#
#
# Nyctophilia
#
# Resonate (Original Mix) - Loco D
#
# 2
#
#
# Nyctophilia
#
# My Nguyen - first 36'
#
# 3
#
#
# Nyctophilia
#
# Nghi - Nyctophilia Session #13
#
# 2
#
#
# Nyctophilia
#
# Nghia - Pioneer TheLAB Invites 21-07-2017
#
# 2
#
#
# Orion Bui
#
# Muzikdapdich
#
# 2
#
#
# Orion Bui
#
# Spring Bring You Back From Memories Teaser
#
# 3
#
#
# Orion Bui
#
# Cloud Number 2 (3 year ago)
#
# 3
#
#
# Orion Bui
#
# Chờ Lời Anh Nói - IVY Ft Crou Produce By OrionB Final
#
# 3
#
#
# Orion Bui
#
# Tuyet Hong Lau
#
# 2
#
#
# Orion Bui
#
# Sunday T ft Orion
#
# 3
#
#
# Orion Bui
#
# Crash of collab - Sau Tat Ca
#
# 2
#
#
# Orion Bui
#
# Boobawbruh
#
# 2
#
#
# Orion Bui
#
# My Bluestone
#
# 3
#
#
# Orion Bui
#
# Goodnight Remixx OrionB happy ver
#
# 2
#
#
# Orion Bui
#
# Sounds from Thứ Tư evening
#
# 2
#
#
# Orion Bui
#
# Cat Song
#
# 2
#
#
# Orion Bui
#
# Trống Vắng
#
# 3
#
#
# Orion Bui
#
# Latch OB ver
#
# 2
#
#
# Orion Bui
#
# Pikiachu
#
# 2
#
#
# Orion Bui
#
# Think Touliver - (Orion Ver)
#
# 2
#
#
# Orion Bui
#
# Empty Universe
#
# 2
#
#
# Orion Bui
#
# Peace Of Mind
#
# 2
#
#
# Orion Bui
#
# Bubble Cloud
#
# 2
#
#
# Orion Bui
#
# My Everything TIEN TIEN Dubstep  2
#
# 2
#
#
# Orion Bui
#
# Nice Clound
#
# 2
#
#
# Orion Bui
#
# For Yew
#
# 2
#
#
# Orion Bui
#
# Mưa đông
#
# 2
#
#
# Orion Bui
#
# Chưa đặt tên !!!
#
# 2
#
#
# Orion Bui
#
# Nothin On Me[1]
#
# 2
#
#
# Orion Bui
#
# Bad Apple
#
# 3
#
#
# Orion Bui
#
# Cánh Đồng Diều
#
# 2
#
#
# Orion Bui
#
# Danh Tien Em Orion Ver[1]
#
# 2
#
#
# Orion Bui
#
# The motions
#
# 3
#
#
# Orion Bui
#
# River crazy in me :)))
#
# 2
#
#
# Orion Bui
#
# Turned off the TV
#
# 2
#
#
# Orion Bui
#
# Scary monster and nice spirit at Piano Room
#
# 2
#
#
# Orion Bui
#
# Fight For Life
#
# 2
#
#
# Orion Bui
#
# Circle 3,14
#
# 3
#
#
# Orion Bui
#
# Come Back To Me
#
# 3
#
#
# Orion Bui
#
# Blue Angel[1]
#
# 3
#
#
# Orion Bui
#
# OB 3.4
#
# 3
#
#
# Orion Bui
#
# Sing Like Me
#
# 3
#
#
# Orion Bui
#
# Illution Mark 1
#
# 2
#
#
# Orion Bui
#
# Flow Of Pi
#
# 2
#
#
# Orion Bui
#
# Maricle
#
# 2
#
#
# Orion Bui
#
# Walk In Dream 2
#
# 3
#
#
# Orion Bui
#
# Cartoon Say Hi
#
# 3
#
#
# Orion Bui
#
# This Christmas (Academy class )
#
# 2
#
#
# Orion Bui
#
# Hear your heart beat
#
# 3
#
#
# Orion Bui
#
# X-Mas Is You
#
# 3
#
#
# Orion Bui
#
# AuTumn
#
# 3
#
#
# VRT
#
# Em Là Hoàng Hôn - Vang x Cloud5 ft Quang Huy | VRT remix
#
# 3
#
#
# VRT
#
# nit, sing - ôm em lần cuối | vrt lofi ver.
#
# 3
#
#
# VRT
#
# HURRYKNG, HIEUTHUHAI, MANBO - 'HẸN GẶP EM DƯỚI ÁNH TRĂNG' | (VRT REMIX)
#
# 3
#
#
# VRT
#
# DẠ VŨ |(BAE)TĂNG DUY TÂN X (BAE)VRT|(Remix)
#
# 3
#
#
# VRT
#
# ‘có hẹn với thanh xuân’ (vrt rnb ver.) - monstar
#
# 3
#
#
# VRT
#
# Da LAB - Thức giấc (VRT Remix)
#
# 3
#
#
# VRT
#
# SAO ANH CHƯA VỀ NHÀ - AMEE (ft. RICKY STAR) | VRT Remix
#
# 3
#
#
# VRT
#
# MÊ CHỮ Ê Ê Ê | JENA ft Bofie (VRT Remix)
#
# 3
#
#
# VRT
#
# TÌNH BẠN DIỆU KỲ - AMEE x RICKY STAR x LĂNG LD (VRT remix)
#
# 3
#
#
# VRT
#
# LIKE MEDICINE ft. HUYTUNE
#
# 3
#
#
# VRT
#
# 80s Remix: 2+3=5 - T.R.I x Cammie
#
# 3
#
#
# VRT
#
# MÌNH ANH NƠI NÀY - NIT ft. SING | VRT lofi ver.
#
# 3
#
#
# VRT
#
# T.R.I - I DON'T NEED YOU ANYMORE | VRT Remix
#
# 3
#
#
# VRT
#
# B'Miles Away - Bring Me Back (VRT Remix)
#
# 3
#
#
# VRT
#
# TOULIVER x BINZ - "BIGCITYBOI" (VRT & CM1X REMIX)
#
# 3
#
#
# VRT
#
# 2+3=5 - T.R.I, Cammie (VRT RMX)
#
# 3
#
#
# VRT
#
# NOI EM MUON TOI - HOAPROX x XESI | VRT x DEYE REMIX
#
# 3
#
#
# VRT
#
# Roy P ft Magazine - Run Away ( Prod. VRT )
#
# 3
#
#
# VRT
#
# TeamV - Bình Yên Nơi Anh (VRT X CM1X Remix)
#
# 3
#
#
# VRT
#
# Cho Anh Instrumental (Free download)
#
# 3
#
#
# VRT
#
# Cùng Anh Instrumental (Free download)
#
# 3
#
#
# VRT
#
# VRT & COX - Comeback (Original mix)
#
# 3
#
#
# VRT
#
# Cùng Anh - Ngọc Dolil x VRT
#
# 3
#
#
# VRT
#
# ĐÃ LỠ YÊU EM NHIỀU - JustaTee ( VRT X C.A.O Remix )
#
# 3
#
#
# Kevinnnz
#
# Có Hẹn Với Thanh Xuân - Monstar
#
# 3
#
#
# Kevinnnz
#
# Đom Đóm
#
# 2
#
#
# Kimmese
#
# Kimmese X Triple D - Triệu Ngọn Lửa Một Khát Vọng
#
# 3
#
#
# Kimmese
#
# Kimmese - Ngoi Nha Xanh Official  Audio
#
# 3
#
#
# Kimmese
#
# Kimmese - YSW Official Audio +Lyric
#
# 3
#
#
# Kimmese
#
# ITSABET  (REMIX CONTEST - JUSTIN TECHN9)
#
# 3
#
#
# Kimmese
#
# ISABET (REMIX CONTEST - PHAN HOANG MINH a.ka W n C)
#
# 3
#
#
# Kimmese
#
# ISABET - (REMIX CONTEST - D.Baola X Lupin)
#
# 3
#
#
# Kimmese
#
# ITSABET (REMIX CONTEST - FUNNYBAT)
#
# 3
#
#
# Kimmese
#
# ITSABET (REMIX CONTEST - Max Benderz)
#
# 3
#
#
# Kimmese
#
# ITSABET ft Andree Right Hand
#
# 3
#
#
# Kimmese
#
# The very first of Loving You Demo a.ka.  Kim Sieu Quan 2
#
# 3
#
#
# Kimmese
#
# Liltle cover song from The Weeknd
#
# 3
#
#
# Kimmese
#
# Loving You Sunny - Kimmese Ft Đen ( Prod.by Touliver & JustaTee )
#
# 3
#
#
# Kimmese
#
# Kimmese - Ngỡ Đâu Tình Đã Quên Mình ( Prod. by Touliver )
#
# 3
#
#
# Kimmese
#
# Love Lung Linh
#
# 3
#
#
# Kimmese
#
# Kimmese  - Green Eyes
#
# 3
#
#
# Kimmese
#
# Make Love To Me
#
# 3
#
#
# Kimmese
#
# Kimmese - Co Nguoi Nghi
#
# 3
#
#
# Kimmese
#
# Kimmese - Emotions ( Karaoke version )
#
# 3
#
#
# Kimmese
#
# Juss Juss Juss ( Khuyên nên dùng cho nhạc chuông, nhạc chờ
#
# 3
#
#
# Kimmese
#
# Kimmese - Your girl is a ho
#
# 3
#
#
# Kimmese
#
# Say goodbye
#
# 3
#
#
# Kimmese
#
# Kimmese ft Antoneus Maximus - Emotions ( Official Audio )
#
# 3
#
#
# Kimmese
#
# BREEZY WIND - CLAYTON FT KIMMESE
#
# 3
#
#
# Kimmese
#
# Kimmese - Someone like you Remix
#
# 3
#
#
# Kimmese
#
# Kimmese - Strong ( English version)
#
# 3
#
#
# Kimmese
#
# Kimmese - Strong
#
# 3
#
#
# Kimmese
#
# Kimmese ft JustaTee - Real Love ( Acoustic version ) Prod. by Touliver
#
# 3
#
#
# Kimmese
#
# Kimmese - Leave Me Prod. by Vagno
#
# 3
#
#
# Kimmese
#
# Feel the beat demo 2 ( Prod. by Touliver )
#
# 3
#
#
# Kimmese
#
# Kimmese - Feel the beat ( demo ) Prod. by Touliver
#
# 3
#
#
# Kimmese
#
# Kimmese-Sunny
#
# 3
#
#
# Kimmese
#
# Kimmese -  U A Jerk Remix (High Quality)
#
# 3
#
#
# Kimmese
#
# Kimmese - Cong tu bot
#
# 3
#
#
# Kimmese
#
# Sex ( 17 YEARS OLD )
#
# 3
#
#
# Kimmese
#
# Crunk it mix1
#
# 2
#
#
# UNK-Team
#
# [UNK-T] Tiếng Việt Giàu Đẹp - T.I.N ft. Daddy Lee
#
# 3
#
#
# UNK-Team
#
# [UNK-T] SuperC - BUÔNG (ft. Kancc)
#
# 3
#
#
# UNK-Team
#
# [UNK-T] Daddy Lee - M
#
# 3
#
#
# UNK-Team
#
# [UNK-T] Goll - f5 (by ka∅5)
#
# 3
#
#
# UNK-Team
#
# [UNK-T] Để Nhớ (InsT)
#
# 2
#
#
# UNK-Team
#
# [UNK-T] Milo Miller - Never Going Down (by ka∅5)
#
# 3
#
#
# UNK-Team
#
# [UNK-T] StillaD - PASS BY (by ka∅5)
#
# 3
#
#
# UNK-Team
#
# [UNK-T] ZC Homiez - VẪN THẾ MÀ
#
# 3
#
#
# UNK-Team
#
# [UNK-T] StillaD - ĐỂ NHỚ
#
# 3
#
#
# UNK-Team
#
# [UNK-T] Ruzz ft. Daddy Lee - THOÁT
#
# 3
#
#
# UNK-Team
#
# Zedd Ft. Jon Bellion -=- Beautiful Now [Remixed By Helliouz]
#
# 3
#
#
# UNK-Team
#
# Yêu Một Nguời Có Lẽ -=- MIU Le ft LOU Hoang
#
# 3
#
#
# UNK-Team
#
# [UNK-T] StillaD ft. Daddy Lee & Milo Miller - XÉT (by ka∅5)
#
# 3
#
#
# UNK-Team
#
# [Rework] Adele -=- Hello (by ka∅5 & Tidus)
#
# 3
#
#
# UNK-Team
#
# [UNK-T] StillaD - AiYe
#
# 3
#
#
# UNK-Team
#
# [UNK-T] SuperC ft. 2Kz & Milo Miller - F.L.U.V
#
# 3
#
#
# UNK-Team
#
# [UNK-T] Daddy Lee ft. StillaD & S.O (Prod. by T.I.N) - TỪNG
#
# 3
#
#
# UNK-Team
#
# [UNK-T] SECRET BEAT
#
# 3
#
#
# UNK-Team
#
# [UNK-T] T.I.N ft. S.O & 2Kz - SECRET
#
# 3
#
#
# UNK-Team
#
# [UNK-T] X [DaSac] T.I.N ft. EmceeL - XALA
#
# 3
#
#
# UNK-Team
#
# [UNK-T] SuperC ft. NDV & Milo Miller - SAI
#
# 3
#
#
# UNK-Team
#
# [UNK-T]  Milo Miller ft. T.I.N & 2Kz & MceeBlue - ĐỐT (by T.I.N & ka∅5)
#
# 3
#
#
# UNK-Team
#
# [UNK-T] T.I.N ft. 2Kz & Daddy Lee & Milo Miller - GỤC (by T.I.N & ka∅5)
#
# 3
#
#
# UNK-Team
#
# [UNK - T] 2K Ft T.I.N - RƠI
#
# 3
#
#
# UNK-Team
#
# [UNK - T] Daddy Lee - Nơi Đâu (.ft G - Little)
#
# 3
#
#
# UNK-Team
#
# [UNK - T] Daddy Lee - Thảo
#
# 3
#
#
# UNK-Team
#
# [UNK - T] Krayzee.A - Love In My Life (.ft LiL' KAnI)
#
# 2
#
#
# UNK-Team
#
# [UNK - T] Krayzee.A - YÊU THƯƠNG VỤT MẤT
#
# 2
#
#
# UNK-Team
#
# [UNK - T] MceeTee - Khi Đêm Về
#
# 2
#
#
# UNK-Team
#
# [UNK - T] MceeTee Ft Mastic - Thường Thôi
#
# 2
#
#
# UNK-Team
#
# [UNK - T] Milo Miller Ft Daddy Lee - Còn Lại
#
# 2
#
#
# UNK-Team
#
# [UNK - T] Tiểu Chuỳ Chuỳ Ft. Jienah, Kancc - Là Ở Nơi Nào
#
# 3
#
#
# UNK-Team
#
# [UNK - T] Tiểu Chuỳ Chuỳ Ft. Tú Lio - Nhìn Lại Xem
#
# 3
#
#
# 𝟹 𝟷 𝟶 𝟽
#
# Nếu Anh Thấy Lòng Mình Yếu Đuối | Tùa&CM1X | Và khi em thấy lòng mình yếu đuối
#
# 2
#
#
# 𝟹 𝟷 𝟶 𝟽
#
# Câu Hứa Chưa Vẹn Tròn (Đại Mèo Remix) | Phát Huy T4 | Mình Đã Hứa Yêu Thật Lâu
#
# 3
#
#
# 𝟹 𝟷 𝟶 𝟽
#
# Như Một Người Dưng (Ciray Remix) | Nguyễn Thạc Bảo Ngọc | Từng ngày anh vẫn bên em thế nhưng
#
# 3
#
#
# 𝟹 𝟷 𝟶 𝟽
#
# Yêu Đừng Sợ Đau (Frexs Remix) | Ngô Lan Hương | Đừng Quay Mặt Đi Nước Mắt Rơi Thì Cứ Hot TikTok
#
# 3
#
#
# 𝟹 𝟷 𝟶 𝟽
#
# Nợ Ai Đó Lời Xin Lỗi (Lofi Ver.) | Bozitt x Freak D
#
# 3
#
#
# 𝟹 𝟷 𝟶 𝟽
#
# Thật Là Đáng Buồn (Lofi Ver.) | Doãn Hiếu | *Đôi khi chẳng biết sẽ đi về đâu...*
#
# 3
#
#
# 𝟹 𝟷 𝟶 𝟽
#
# Người Lạ Thoáng Qua (Lofi Ver.) | Đinh Tùng Huy | *Vậy mà em nỡ buông tay anh rồi...*
#
# 3
#
#
# 𝟹 𝟷 𝟶 𝟽
#
# Chúng Ta Chỉ Là Đã Từng Yêu(Remix)| Thiên Tú | *Người từng mang bao câu hẹn ước*
#
# 3
#
#
# 𝟹 𝟷 𝟶 𝟽
#
# Chạy về nơi phía anh | Khắc Việt (Demo)
#
# 2
#
#
# 𝟹 𝟷 𝟶 𝟽
#
# Lỗi Tại Anh (Lofi Ver.) | Alex Lam x FreakD
#
# 3
#
#
# 𝟹 𝟷 𝟶 𝟽
#
# Chỉ Là Muốn Nói (Lofi Ver.) | Khải x FreakD
#
# 2
# Cloud 5
#
# ĐỘ TỘC 2 (GEMME REMIX) | MASEW X PHÚC DU X PHÁO X ĐỘ MIXI
#
# 3
#
#
# Cloud 5
#
# HOÀNG TÔN - Tình Yêu Ngủ Quên - Iris x Cloud 5 Remix
#
# 3
#
#
# Cloud 5
#
# Em Là Hoàng Hôn - Vang x CLoud 5
#
# 3
#
#
# Cloud 5
#
# Cho Anh Một Chút Hy Vọng - Haukong ft Flymingo - Cloud 5 Mix
#
# 3
#
#
# Cloud 5
#
# Từ Thích Thích Thành Thương Thương - Amee & Hoàng Dũng - Cloud5 x Kvans mix
#
# 3
#
#
# Cloud 5
#
# OOH JUST YOU ~ LÊ THIỆN HIẾU (CuD x Cloud5 Mix)
#
# 3
#
#
# Cloud 5
#
# 95% Tâm Trí Là Em | ImD, ThaiTan, Cloud 5
#
# 3
#
#
# Cloud 5
#
# YÊU LẠI CHÚT THÔI (#song711) - Clow x Linh Thộn - Cloud5 lofi mix
#
# 3
#
#
# odayconhacthuii
#
# Nắm Đôi Bàn Tay - Cover by Pay
#
# 3
#
#
# odayconhacthuii
#
# Brooksie - Not Into You
#
# 3
#
#
# odayconhacthuii
#
# WREN EVANS - Thích Em Hơi Nhiều
#
# 3
#
#
# odayconhacthuii
#
# DEMO NGÀY VÀ ĐÊM - NOEN X PAWN
#
# 3
#
#
# odayconhacthuii
#
# Tôi Biết Em Không Biết - Kiên
#
# 3
#
#
# odayconhacthuii
#
# 愛，籽，花 (Love, Seed, Flower) - 张钰 (Zhang Yu)
#
# 3
#
#
# odayconhacthuii
#
# Cánh Hồng Phai - Phạm Nguyên Ngọc Cover Guitar
#
# 3
#
#
# odayconhacthuii
#
# Duyên trời lấy 2 || Cover guitar Nguyễn Thế Diện
#
# 3
#
#
# Trí Beat
#
# Cưới Thôi - Masew x Masiu x B Ray x TAP - Tik Tok
#
# 3
#
#
# Trí Beat
#
# Người Em Cố Đô Remix - Cukak Remix - Rum ft Đaa - Tik Tok - Deep House
#
# 3
#
#
# Trí Beat
#
# Muộn Rồi Mà Sao Còn Remix - Trí Beat Remix - Sơn Tùng M-TP - Deep House Chill Ke Tik Tok
#
# 3
#
#
# Trí Beat
#
# Muộn Rồi Mà Sao Còn - Sơn Tùng M-TP - Bản Full Audio Giật Mình Lần 1
#
# 3
#
#
# Trí Beat
#
# Bên Anh Đêm Nay Remix - DJ Hạnh Ketamin - Tik Tok - Vinahouse Hay Nhất
#
# 3
#
#
# Trí Beat
#
# Phải Chăng Em Đã Yêu Remix - Phong Max Remix - Juky San ft RedT - Deep House - Tik Tok
#
# 3
#
#
# Trí Beat
#
# DJ Waka Waka Remix Full Bass Indo Tik Tok
#
# 2
#
#
# Trí Beat
#
# Vầng Trăng Khóc Remix - Dj Long Nhật - Tik Tok - Vinahouse
#
# 3
#
#
# Trí Beat
#
# Bản Tình Ca Ngọt Ngào Nhất Remix - ProgHouse Remix - Tik Tok
#
# 2
#
#
# Trí Beat
#
# Chuyện Rằng - Thịnh Suy - CUKAK Remix - Tik Tok - Deep House
#
# 3
#
#
# Trí Beat
#
# Legend Boy - How cute!  feat. SK MTXF x ไกด์ ฟิสิกส์ - Lofi Chill Tik Tok
#
# 3
#
#
# Trí Beat
#
# Comethru Remix - Thành Drake Remix - Jeremy Zucker  - Deep House - Tik Tok
#
# 3
#
#
# Trí Beat
#
# Dancing With Your Ghost 2020 - ARS Remix - Tik Tok
#
# 3
#
#
# fishy
#
# fishy ft Trí Dũng - Forget me now
#
# 3
#
#
# fishy
#
# fishy ft Trí Dũng - 5-minute date
#
# 3
#
#
# fishy
#
# fishy ft Trí Dũng - After love
#
# 3
#
#
# fishy
#
# fishy ft Trí Dũng - White rain(intro)
#
# 3
#
#
# fishy
#
# fishy - The clouds
#
# 3
#
#
# fishy
#
# fishy - My mona lisa
#
# 3
#
#
# 𝚑𝚞𝚠𝚗𝚐
#
# Ánh sao và bầu trời || Cover by Ling Thỏ
#
# 3
#
#
# 𝚑𝚞𝚠𝚗𝚐
#
# Dịu dàng em đến (Lofi) || Erik x Quanvrox
#
# 3
#
#
# 𝚑𝚞𝚠𝚗𝚐
#
# if i ain't got you || Rosé x Suhyun x Onew
#
# 3
#
#
# 𝚑𝚞𝚠𝚗𝚐
#
# 𝘛𝘩𝘪𝘤𝘩 𝘦𝘮 𝘩𝘰𝘪 𝘯𝘩𝘪𝘦𝘶 || 𝘤𝘰𝘷𝘦𝘳 𝘣𝘺 𝘏𝘦𝘬𝘪𝘪
#
# 2
#
#
# 𝚑𝚞𝚠𝚗𝚐
#
# Phố Đã Lên Đèn ||「Lofi Version by 1 9 6 7」
#
# 3
#
#
# 𝚑𝚞𝚠𝚗𝚐
#
# 𝘋𝘶𝘰𝘯𝘨 𝘵𝘰𝘪 𝘤𝘩𝘰 𝘦𝘮 𝘷𝘦  || 𝘤𝘰𝘷𝘦𝘳 𝘣𝘺 𝘕𝘨𝘶𝘺𝘦𝘯 𝘛𝘩𝘪 𝘚𝘶𝘰𝘯𝘨 𝘈𝘯𝘩
#
# 3
#
#
# 𝚑𝚞𝚠𝚗𝚐
#
# 𝒐𝒏𝒍𝒚 𝒎𝒆 || 𝑳𝒆𝒏𝒂 𝒙 𝑷𝑨𝒀 / 𝑴.𝑨.𝑫 𝑺𝑻𝑼𝑫𝑰𝑶
#
# 3
#
#
# 𝚑𝚞𝚠𝚗𝚐
#
# 𝑴𝒖𝒐𝒏 𝒓𝒐𝒊 𝒎𝒂 𝒔𝒂𝒐 𝒄𝒐𝒏 || 𝑮𝒖𝒊𝒕𝒂𝒓 𝒄𝒐𝒗𝒆𝒓 𝒃𝒚 𝑴𝒂𝒊𝑨𝒏𝒉𝑻𝒂𝒊
#
# 3
#
#
# 𝚑𝚞𝚠𝚗𝚐
#
# 𝚛𝚊𝚗𝚐 𝚔𝚑𝚘𝚗 || 𝙼𝚒𝚗𝚊 𝚌𝚘𝚟𝚎𝚛
#
# 3
#
#
# 𝚑𝚞𝚠𝚗𝚐
#
# 3107 - 2 || 𝘤𝘰𝘷𝘦𝘳 𝘣𝘺 𝘛𝘩𝘶𝘺 𝘈𝘯
#
# 3
#
#
# 𝚑𝚞𝚠𝚗𝚐
#
# 𝘷𝘪 𝘦𝘮 𝘯𝘩𝘰 𝘢𝘯𝘩 || 𝘤𝘰𝘷𝘦𝘳 𝘣𝘺 𝘓𝘺𝘭𝘺
#
# 2
#
#
# YC
#
# Big City Noise Test - Rhymastic
#
# 3
#
#
# YC
#
# Nụ Cười - Rhymastic
#
# 3
#
#
# YC
#
# Can Gi Hon Remix
#
# 3
#
#
# YC
#
# Mặt Trời Của Em - Phương Ly feat. JustaTee (Rhymastic's 1900 Remix)
#
# 3
#
#
# YC
#
# Treasure Vocal 90bpm
#
# 3
#
#
# YC
#
# Treasure Instrumental 90bpm
#
# 3
#
#
# YC
#
# Wet Lens Remix
#
# 3
#
#
# YC
#
# Ech Bao Dissin - Young Crizzal
#
# 3
#
#
# YC
#
# Bray Dissin
#
# 3
#
#
# YC
#
# Ngược Đời - Rhymastic
#
# 3
#
#
# YC
#
# Bản Kiểm Điểm - Rhymastic
#
# 3
#
#
# YC
#
# Hanh Trinh Cua Giot Nang
#
# 3
#
#
# YC
#
# Ve Khoi (Bass House Remix)
#
# 3
#
#
# YC
#
# Paranoid (Original Mix) [Demo Preview]
#
# 3
#
#
# YC
#
# Vut Tan (Gala)
#
# 3
#
#
# YC
#
# Vui Di Em (Chung Ket)
#
# 3
#
#
# YC
#
# Sorry (Vong 8)
#
# 3
#
#
# YC
#
# Tim Lai Reu Phong (Vong 7)
#
# 3
#
#
# YC
#
# Ai Kho Vi Ai (Vong 6)
#
# 3
#
#
# YC
#
# Ve Khoi (Vong 5)
#
# 3
#
#
# YC
#
# Chi Toi (Vong 4)
#
# 3
#
#
# YC
#
# Chuyen Chang Co Don (Vong 2)
#
# 3
#
#
# YC
#
# Day Dream (Vong 1)
#
# 3
#
#
# YC
#
# Nguoi Va Ta (Instrumental)
#
# 3
#
#
# YC
#
# Người và Ta (feat. Thanh Huyền)
#
# 3
#
#
# YC
#
# Valentine - Miko Lan Trinh (Rhymastic Edit)
#
# 3
#
#
# YC
#
# Happy Birthday Song
#
# 3
#
#
# YC
#
# Old School - Rhymastic
#
# 3
#
#
# YC
#
# Xilevolau (Melodic Deep House Remix)
#
# 3
#
#
# YC
#
# Sau Trong Em (Disco Remix)
#
# 3
#
#
# YC
#
# Ban Khoan feat. Duong Tran Nghia (Rhymastic Trap Remix)
#
# 3
#
#
# YC
#
# Do You Remember - Duong Tran Nghia feat. Mr.A (Rhymastic Remix)
#
# 3
#
#
# YC
#
# Cho Em Mot Ngay (Hard Dance Remix) [Tuyet Dinh Tranh Tai Drop Release]
#
# 3
#
#
# YC
#
# Say You Do - Tiên Tiên (Future Funk Remix) [Preview]
#
# 3
#
#
# YC
#
# DeepCME
#
# 3
#
#
# YC
#
# Valentine ft. Miko Lan Trinh (Deep House Remix)
#
# 3
#
#
# YC
#
# Deep Against The World (Rhymastic's Extended Mix)
#
# 3
#
#
# YC
#
# Rieng Minh Ta (Original Mix)
#
# 3
#
#
# YC
#
# Yeu 4
#
# 3
#
#
# YC
#
# Băn Khoăn (feat. Dương Trần Nghĩa)
#
# 3
#
#
# YC
#
# Sad Flow
#
# 3
#
#
# YC
#
# Yeu 3 (Acapella)
#
# 3
#
#
# YC
#
# Yêu part 1
#
# 3
#
#
# YC
#
# Two Against The World - Lil Knight (Rhymastic's House Remix)
#
# 3
#
#
# YC
#
# I Will Be Fine - Yanbi feat. Rhymastic
#
# 3
#
#
# YC
#
# Tìm (Original Mix)
#
# 3
#
#
# YC
#
# Lạc - Rhymastic
#
# 3
#
#
# YC
#
# Diss G Fam
#
# 3
#
#
# YC
#
# Diss Acy Final
#
# 3
#
#
# YC
#
# Diss Acy 2
#
# 3
#
#
# YC
#
# Diss Acy
#
# 3
#
#
# YC
#
# Diss ngu si
#
# 3
#
#
# YC
#
# ATOG
#
# 3
#
#
# YC
#
# Khi tao ra tay 2 - Rhymastic feat. Da Vickie & Silver C
#
# 3
#
#
# YC
#
# Homie - Rhymastic
#
# 3
#
#
# YC
#
# Can - Rhymastic feat. Soobin
#
# 3
#
#
# YC
#
# Amarant Vinahouse Remix - Com feat. Danny & CK Babe
#
# 3
#
#
# YC
#
# Loi yeu thuong - Com feat. Cuong Ngo & Danny
#
# 3
#
#
# YC
#
# Neu may la rapper (full version)
#
# 3
#
#
# YC
#
# Đam Mê - Rhymastic
#
# 3
#
#
# DARLING
#
# Nằm Ngủ Em Ru - Bích Phương ( DARLING REMIX ) TIKTOK
#
# 3
#
#
# DARLING
#
# Ái Nộ - Masew x Khoi Vu( Vinniedepooh ft Darling remix ) Hot TikTok
#
# 3
#
#
# DARLING
#
# Chờ Lời Anh Nói – Ivy Ft Crou ( Lofi Ver By DARLING )
#
# 3
#
#
# DARLING
#
# Mùi Hương Em Nồng Say - Văn Mai Hương ( DARLING REMIX ) / TikTok
#
# 3
#
#
# DARLING
#
# Cưới Thôi - Masew x Masiu x B Ray x TAP
#
# 3
#
#
# DARLING
#
# YÊU LÀ CƯỚI - PHÁT HỒ X2X ( LOFI VER BY DARLING )
#
# 3
#
#
# DARLING
#
# Dịu Dàng Em Đến - ERIK x DARLING( Lofi Version )
#
# 3
#
#
# DARLING
#
# DẠ VŨ ( LOFI VER BY DARLING ) - TĂNG DUY TÂN (BAE)
#
# 3
#
#
# DARLING
#
# 3107-3 (Lofi x Chill ke) / W/n x Dương x Nâu x Titie ( DARLING REMIX )
#
# 3
#
#
# DARLING
#
# THỨC GIẤC - DaLAB ( DARLING REMIX ) /TIKTOK
#
# 3
#
#
# DARLING
#
# ĐẮM - XESI x RICKY STAR ( DARLING REMIX )
#
# 3
#
#
# DARLING
#
# LẦN HẸN HÒ ĐẦU TIÊN - HUYỀN TÂM MÔN (DARLING REMIX)
#
# 3
#               User Name                                         Track Name  \
# 0     Hustlang Winno 🐉🐍                  Tell Ur Mom II - Winno (ft Heily)
# 1     Hustlang Winno 🐉🐍                     Lil Thang - pu ekvw Ft Hashone
# 2     Hustlang Winno 🐉🐍                     Bốp 2 - Winno (Godthic dissin)
# 3     Hustlang Winno 🐉🐍                       Bốp - Winno (Reply Zuyngusi)
# 4     Hustlang Winno 🐉🐍                        Bounce. (remixbyMoTienSinh)
# ...                 ...                                                ...
# 1884            DARLING  DẠ VŨ ( LOFI VER BY DARLING ) - TĂNG DUY TÂN (...
# 1885            DARLING  3107-3 (Lofi x Chill ke) / W/n x Dương x Nâu x...
# 1886            DARLING        THỨC GIẤC - DaLAB ( DARLING REMIX ) /TIKTOK
# 1887            DARLING          ĐẮM - XESI x RICKY STAR ( DARLING REMIX )
# 1888            DARLING  LẦN HẸN HÒ ĐẦU TIÊN - HUYỀN TÂM MÔN (DARLING R...
#
#                  Post Time            Plays  Likes
# 0      Posted 4 months ago  1,611,431 plays  24.8K
# 1      Posted 5 months ago     49,299 plays    614
# 2      Posted 9 months ago    230,319 plays  1,407
# 3     Posted 11 months ago     71,541 plays    614
# 4        Posted 1 year ago      4,678 plays     57
# ...                    ...              ...    ...
# 1884   Posted 2 months ago     94,337 plays    677
# 1885   Posted 3 months ago    197,596 plays    421
# 1886   Posted 3 months ago    282,601 plays  1,302
# 1887   Posted 3 months ago     30,885 plays    274
# 1888   Posted 4 months ago     21,966 plays    227
#
# [1889 rows x 5 columns]

# %%
Users = pd.read_csv('./Crawl_data/users.csv')
Users
