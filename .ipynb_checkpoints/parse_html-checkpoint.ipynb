# %% [markdown]
# ## Members
# - Cao Thanh Khiết   19120544
# - Ninh Duy Huy      19120533
# - Lê Minh Hữu       19120525
# - Nguyễn Tuấn Khoa  19120547
# - Trần Tuấn Kiệt    19120557
# # Task of each member
# - Cao Thanh Khiết
#     - Use SoundClound API to get data and write down them into csv file
# - Ninh Duy Huy
#     - Parse HTML to get data and write down them into csv file
# - Lê Minh Hữu
#     - Parse HTML to get data and write down them into csv file
# - Nguyễn Tuấn Khoa
#     - Parse HTML to get data and write down them into csv file
# - Trần Tuấn Kiệt
#     - Parse HTML to get data and write down them into csv file

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\DELL\\miniconda3\\envs\\min_ds-env\\python.exe'

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import time
import json
import re
import pandas as pd # Dùng để đọc và hiển thị file csv/tsv
from datetime import datetime, timedelta # Dùng để xử lý dữ liệu thời gian
import os
import urllib.robotparser # Kiểm tra file robot.txt có được phép crawl không
from selenium import webdriver

# %%
def GetAllUrls(filename):
    
    urls = []
    with open(filename, 'r') as f:
        while f.tell() != os.fstat(f.fileno()).st_size:
            url = f.readline()
            if url != '':
                url = url.replace('\n','')
                urls.append(url)
    f.close()
    return urls

def GetUsers(urls):
    Users = []
    Users.append([])
    Users.append([])
    
    main_url = 'https://soundcloud.com'
    
    for url in urls:
        UsersLink = []
        UsersName = []
        
        chrome_options = webdriver.ChromeOptions()
        prefs = {
            "profile.managed_default_content_settings.images": 2
        }
        chrome_options.add_experimental_option("prefs", prefs)
        
        browser = webdriver.Chrome(executable_path="chromedriver.exe", options=chrome_options)
        browser.get(url)
        time.sleep(1)

        # To make it load more scroll to the bottom of the page (repeat if you want to)

        lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
        match = False
        while(match == False):
            lastCount = lenOfPage
            time.sleep(1)
            lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
            if lastCount == lenOfPage:
                    match = True

        html_source = browser.page_source
        browser.quit()
        soup = BeautifulSoup(html_source, 'html.parser')
        for id in soup.findAll('a', {'class' : 'trackItem__username sc-link-light sc-link-secondary'}):
            UsersLink.append(main_url + str(id.get('href')))
            UsersName.append(id.text)
        
        #đoạn này nối chuỗi mới vào Users[0], Users[1], Users[2]
        Users[0] += UsersLink 
        Users[1] += UsersName
        
    return Users

def GetUserInfo(Users):
    Users.append([]) #append follower column
    Users.append([]) #append following column
    Users.append([]) #append tracks column
    sizeOfUserName = len(Users[0])
    
    for i in range(sizeOfUserName):
        url = Users[0][i] #lay duong dan den user
        
        chrome_options = webdriver.ChromeOptions()
        prefs = {
            "profile.managed_default_content_settings.images": 2
        }
        
        chrome_options.add_experimental_option("prefs", prefs)
        browser = webdriver.Chrome(executable_path="chromedriver.exe", options=chrome_options)
        browser.get(url)
        time.sleep(3)
        
        # xóa phần cuộn đến cuối trang
        html_source = browser.page_source
        browser.quit()

        soup = BeautifulSoup(html_source, 'html.parser')
        checks = soup.find_all('div', {'class' : 'infoStats__value sc-font-light'})
        Users[2].append(checks[0].text)
        Users[3].append(checks[1].text)
        Users[4].append(checks[2].text)
        
    return Users

def GetTracks(Users):
    TracksOfAllUsers = []
    TracksOfAllUsers.append([]) #tên mỗi user
    TracksOfAllUsers.append([]) #tên mỗi track của user
    TracksOfAllUsers.append([]) #lấy thời gian post
    TracksOfAllUsers.append([]) #lấy lượt nghe
    TracksOfAllUsers.append([]) #lấy lượt thich
    
    for i in range(len(Users[0])):
        UserName = []
        TrackName = []
        PostTime = []
        Plays = []
        Likes = []
        #----------------------------
        url = str(Users[0][i]) + '/tracks'
        
        chrome_options = webdriver.ChromeOptions()
        prefs = {
            "profile.managed_default_content_settings.images": 2
        }
        chrome_options.add_experimental_option("prefs", prefs)
        
        browser = webdriver.Chrome(executable_path="chromedriver.exe", options=chrome_options)
        browser.get(url)
        time.sleep(1)

        # To make it load more scroll to the bottom of the page (repeat if you want to)
        
        lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
        match = False
        while(match == False):
            lastCount = lenOfPage
            time.sleep(1)
            lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
            if lastCount == lenOfPage:
                match = True
                
        html_source = browser.page_source
        browser.quit()
        
        soup = BeautifulSoup(html_source, 'html.parser')
        check = soup.findAll('div', {'class' : 'sound__content'})
        if check == []:
            UserName.append(Users[1][i])
            TrackName.append('None')
            PostTime.append('None')
            Plays.append('None')
            Likes.append('None')
            
            TracksOfAllUsers[0] += UserName
            TracksOfAllUsers[1] += TrackName
            TracksOfAllUsers[2] += PostTime
            TracksOfAllUsers[3] += Plays
            TracksOfAllUsers[4] += Likes
        else:
            for id in check:
                UserName = []
                TrackName = []
                PostTime = []
                Plays = []
                Likes = []
        
                UserName.append(Users[1][i])
            
                trackname = id.find('a', {'class' : 'sc-link-primary soundTitle__title sc-link-dark sc-text-h4'})
                Like = id.find('button', {'class' : 'sc-button-like sc-button-secondary sc-button sc-button-small sc-button-responsive'})
                info = id.findAll('span', {'class' : 'sc-visuallyhidden'})
            
                TrackName.append(trackname.text.replace('\n', ''))
                PostTime.append(info[0].text.replace('\n', '')) #lay thoi gian post
                
                if len(info) < 2:
                    Plays.append('0')
                    Likes.append('0')
                else:
                    Plays.append(info[1].text.replace('\n', '')) #lay luot xem
                    Likes.append(Like.text.replace('\n', ''))
                    
                TracksOfAllUsers[0] += UserName
                TracksOfAllUsers[1] += TrackName
                TracksOfAllUsers[2] += PostTime
                TracksOfAllUsers[3] += Plays
                TracksOfAllUsers[4] += Likes
    return TracksOfAllUsers

def GetPlaylists(Users):
    PlaylistOfAllUsers = []
    PlaylistOfAllUsers.append([])
    PlaylistOfAllUsers.append([])
    PlaylistOfAllUsers.append([])
    
    for i in range(len(Users[0])):
        UserNames = []
        PlaylistNames = []
        TrackNames = []
        
        url = str(Users[0][i]) + '/sets' #lay duong dan den playlist
        
        chrome_options = webdriver.ChromeOptions()
        prefs = {
            "profile.managed_default_content_settings.images": 2
        }
        chrome_options.add_experimental_option("prefs", prefs)
        
        browser = webdriver.Chrome(executable_path="chromedriver.exe", options=chrome_options)
        browser.get(url)
        time.sleep(1)

        # To make it load more scroll to the bottom of the page (repeat if you want to)
        
        lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
        match = False
        while(match == False):
            lastCount = lenOfPage
            time.sleep(1)
            lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
            if lastCount == lenOfPage:
                match = True
                
        html_source = browser.page_source
        browser.quit()
        
        soup = BeautifulSoup(html_source, 'html.parser')
        check = soup.findAll('div', {'class' : 'sound__content'})
        if check == []:
            UserNames.append(Users[1][i])
            PlaylistNames.append('None')
            TrackNames.append('None')
            
            PlaylistOfAllUsers[0] += UserNames
            PlaylistOfAllUsers[1] += PlaylistNames
            PlaylistOfAllUsers[2] += TrackNames
        else:        
            for id in check:
                Title = id.find('a', {'class' : 'sc-link-primary soundTitle__title sc-link-dark sc-text-h4'})
                Tracks = id.findAll('span', {'class' : 'compactTrackListItem__trackTitle sc-text-primary sc-text-h4'})
                for Track in Tracks:
                    UserNames = []
                    PlaylistNames = []
                    TrackNames = []
                    
                    UserNames.append(Users[1][i])
                    PlaylistNames.append(Title.text.replace('\n', ''))
                    TrackNames.append(Track.text.replace('\n', ''))
                    
                    PlaylistOfAllUsers[0] += UserNames
                    PlaylistOfAllUsers[1] += PlaylistNames
                    PlaylistOfAllUsers[2] += TrackNames
    return PlaylistOfAllUsers

def writeUsersToCsv(List5D, filename):
    df = pd.DataFrame({
        'Users Link': pd.Series(link for link in List5D[0]),
        'User Name': pd.Series(name for name in List5D[1]),
        'Followers': pd.Series(fle for fle in List5D[2]),
        'Following': pd.Series(fli for fli in List5D[3]),
        'Tracks': pd.Series(track for track in List5D[4]),
    })
    df.to_csv(filename, index = False)
    
def writeTracksToCsv(List5D, filename):
    df = pd.DataFrame({
        'User Name': pd.Series(user for user in List5D[0]),
        'Track Name': pd.Series(track for track in List5D[1]),
        'Post Time' : pd.Series(t for t in List5D[2]),
        'Plays' : pd.Series(p for p in List5D[3]),
        'Likes' : pd.Series(L for L in List5D[4]),
    })
    df.to_csv(filename, index = False)

def writePlaylistsToCsv(List3D, filename):
    df = pd.DataFrame({
        'User Name': pd.Series(user for user in List3D[0]),
        'Playlist Name': pd.Series(p for p in List3D[1]),
        'Track Name' : pd.Series(t for t in List3D[2]),
    })
    df.to_csv(filename, index = False)

# %%
#Lay du lieu tu cac link tong file top50_url.txt
filename = './url_entry/top50_url.txt'
urls = GetAllUrls(filename)

#lay users, tracks, playlists

users_Top50 = GetUsers(urls)
#users_Top50 = GetUserInfo(users_Top50)
#Ghi xuong file csv
#writeUsersToCsv(users_Top50, './Crawl_data/users.csv')


#tracks_Top50 = GetTracks(users_Top50)
#Ghi xuong file csv
#writeTracksToCsv(tracks_Top50, './Crawl_data/tracks.csv')

playlists_Top50 = GetPlaylists(users_Top50)
#Ghi xuong file csv
writePlaylistsToCsv(playlists_Top50, './Crawl_data/playlists.csv')

# %%
#lay ban du lieu tu top50_url.txt
Users = pd.read_csv('./Crawl_data/users.csv')
Users
# Out:
#                                        Users Link                 User Name  \
# 0           https://soundcloud.com/winnodamidside         Hustlang Winno 🐉🐍
# 1            https://soundcloud.com/t-h-i-n-h-h-o                   THINHHO
# 2             https://soundcloud.com/youngcrizzal                        YC
# 3    https://soundcloud.com/hieutranmusicproducer  Hieu Tran Music Producer
# 4               https://soundcloud.com/l2share140               L2Share♫140
# ..                                            ...                       ...
# 241  https://soundcloud.com/t-ng-nguy-n-603782925               Tùng Nguyễn
# 242     https://soundcloud.com/quang-le-819563502                  Quang Le
# 243                  https://soundcloud.com/huydx                     Huydx
# 244       https://soundcloud.com/gherardofabrizio         Gherardo Fabrizio
# 245        https://soundcloud.com/h-a-t-511862450                   Minh Tú
#
#     Followers Following  Tracks
# 0       9,659       241      24
# 1         205       230       1
# 2        125K        47      74
# 3       2,608         2      79
# 4       2,618        97      34
# ..        ...       ...     ...
# 241        35         5       3
# 242        65         1       8
# 243     28.3K       802      58
# 244     4,069       558       8
# 245     2,757       759       4
#
# [246 rows x 5 columns]

# %%
Tracks = pd.read_csv('./Crawl_data/tracks.csv')
Tracks
# Out:
#               User Name                                         Track Name  \
# 0     Hustlang Winno 🐉🐍                  Tell Ur Mom II - Winno (ft Heily)
# 1     Hustlang Winno 🐉🐍                     Lil Thang - pu ekvw Ft Hashone
# 2     Hustlang Winno 🐉🐍                     Bốp 2 - Winno (Godthic dissin)
# 3     Hustlang Winno 🐉🐍                       Bốp - Winno (Reply Zuyngusi)
# 4     Hustlang Winno 🐉🐍                        Bounce. (remixbyMoTienSinh)
# ...                 ...                                                ...
# 8723  Gherardo Fabrizio                                      Feel The Love
# 8724            Minh Tú  | MIXTAPE | - Lớp Chúng Mình Rất Rất Zuii - Mi...
# 8725            Minh Tú     My Style My Name - VOL 28 TILO MIX ( Bản Sao )
# 8726            Minh Tú      My Style My Name - VOL 29 TILO MIX (Bản Sao )
# 8727            Minh Tú              Chỉ Là - Trang Pháp - Long Nhật Remix
#
#                  Post Time            Plays  Likes
# 0      Posted 4 months ago  1,614,424 plays  24.8K
# 1      Posted 5 months ago     49,312 plays    614
# 2      Posted 9 months ago    230,340 plays  1,407
# 3     Posted 11 months ago     71,542 plays    614
# 4        Posted 1 year ago      4,678 plays     57
# ...                    ...              ...    ...
# 8723    Posted 2 years ago     21,250 plays    611
# 8724    Posted 1 month ago      1,676 plays     78
# 8725   Posted 4 months ago     25,816 plays    962
# 8726   Posted 4 months ago    114,104 plays  4,040
# 8727    Posted 2 years ago  1,023,053 plays  12.2K
#
# [8728 rows x 5 columns]

# %%
Playlists = pd.read_csv('./Crawl_data/playlists.csv')
Playlists
# Out:
#               User Name         Playlist Name  \
# 0     Hustlang Winno 🐉🐍                  None
# 1               THINHHO                  None
# 2                    YC  Tren Lau Cao Remixes
# 3                    YC  Tren Lau Cao Remixes
# 4                    YC  Tren Lau Cao Remixes
# ...                 ...                   ...
# 1683  Gherardo Fabrizio                  Deep
# 1684  Gherardo Fabrizio                  Deep
# 1685  Gherardo Fabrizio                  Deep
# 1686            Minh Tú       Album PINK Tilo
# 1687            Minh Tú       Album PINK Tilo
#
#                                              Track Name
# 0                                                  None
# 1                                                  None
# 2         Rhymastic - Trên Lầu Cao ( Zan x TeaA remi...
# 3              Rhymastic - Trên Lầu Cao (Alden Remix)
# 4                                          TRENLAUCAO
# ...                                                 ...
# 1683      Beau Collins & Osrin - Wonderland (feat. M...
# 1684          Simon Valente - Stunnin' (Original Mix)
# 1685      Mr. Belt & Wezol, Aevion - One More Day [O...
# 1686      My Style My Name - VOL 28 TILO MIX ( Bản S...
# 1687      My Style My Name - VOL 29 TILO MIX (Bản Sa...
#
# [1688 rows x 3 columns]
