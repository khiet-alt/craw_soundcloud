# %% [markdown]
# ## Members
# - Cao Thanh Khiết   19120544
# - Ninh Duy Huy      19120533
# - Lê Minh Hữu       19120525
# - Nguyễn Tuấn Khoa  19120547
# - Trần Tuấn Kiệt    19120557
# # Task of each member
# - Cao Thanh Khiết
#     - Use SoundClound API to get data and write down them into csv file
# - Ninh Duy Huy
#     - Parse HTML to get data and write down them into csv file
# - Lê Minh Hữu
#     - Parse HTML to get data and write down them into csv file
# - Nguyễn Tuấn Khoa
#     - Parse HTML to get data and write down them into csv file
# - Trần Tuấn Kiệt
#     - Parse HTML to get data and write down them into csv file

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\DELL\\miniconda3\\envs\\min_ds-env\\python.exe'

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import time
import json
import re
import pandas as pd # Dùng để đọc và hiển thị file csv/tsv
from datetime import datetime, timedelta # Dùng để xử lý dữ liệu thời gian
import os
import urllib.robotparser # Kiểm tra file robot.txt có được phép crawl không
from selenium import webdriver

# %%
def GetAllUrls(filename):
    
    urls = []
    with open(filename, 'r') as f:
        while f.tell() != os.fstat(f.fileno()).st_size:
            url = f.readline()
            if url != '':
                url = url.replace('\n','')
                urls.append(url)
    f.close()
    return urls

def GetUsers(urls):
    Users = []
    
    main_url = 'https://soundcloud.com'
    for url in urls:
        chrome_options = webdriver.ChromeOptions()
        prefs = {
            "profile.managed_default_content_settings.images": 2
        }
        chrome_options.add_experimental_option("prefs", prefs)
        
        browser = webdriver.Chrome(executable_path="chromedriver.exe", options=chrome_options)
        browser.get(url)
        time.sleep(1)

        # To make it load more scroll to the bottom of the page (repeat if you want to)

        lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
        match = False
        while(match == False):
            lastCount = lenOfPage
            time.sleep(1)
            lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
            if lastCount == lenOfPage:
                    match = True

        html_source = browser.page_source
        browser.quit()
        soup = BeautifulSoup(html_source, 'html.parser')
        for id in soup.findAll('a', {'class' : 'trackItem__username sc-link-light sc-link-secondary'}):
            UsersTemp = []

            UsersTemp.append(main_url + str(id.get('href')))
            UsersTemp.append(str(id.get('href'))) #lay link de di den tracks va playlist cua moi user
            UsersTemp.append(id.text) #lay username

            Users.append(UsersTemp)
        
    return Users

def GetTracks(Users):
    TracksOfAllUsers = []
    
    for i in range(len(Users)):
        TrackOfOneUser = []
        
        url = 'https://soundcloud.com'
        url = url + str(Users[i][1]) + '/tracks'
        
        chrome_options = webdriver.ChromeOptions()
        prefs = {
            "profile.managed_default_content_settings.images": 2
        }
        chrome_options.add_experimental_option("prefs", prefs)
        
        browser = webdriver.Chrome(executable_path="chromedriver.exe", options=chrome_options)
        browser.get(url)
        time.sleep(1)

        # To make it load more scroll to the bottom of the page (repeat if you want to)
        
        lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
        match = False
        while(match == False):
            lastCount = lenOfPage
            time.sleep(1)
            lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
            if lastCount == lenOfPage:
                match = True
                
        html_source = browser.page_source
        browser.quit()
        
        soup = BeautifulSoup(html_source, 'html.parser')
        check = soup.findAll('a', {'class' : 'sc-link-primary soundTitle__title sc-link-dark sc-text-h4'})
        if check == []:
            TrackOfOneUser.append(Users[i][2])
            TrackOfOneUser.append('None')
            TracksOfAllUsers.append(TrackOfOneUser)
        else:
            for id in check:
                TrackOfOneUser = []
                TrackOfOneUser.append(Users[i][2])
                TrackOfOneUser.append(id.text) #lay track cua 1 user
                TracksOfAllUsers.append(TrackOfOneUser)
    return TracksOfAllUsers

def GetPlaylists(Users):
    PlaylistOfAllUsers = []
    
    for i in range(len(Users)):
        InfoOfOnePlaylist = []
        
        url = 'https://soundcloud.com'
        url = url + str(Users[i][1]) + '/sets' #lay duong dan den playlist
        
        chrome_options = webdriver.ChromeOptions()
        prefs = {
            "profile.managed_default_content_settings.images": 2
        }
        chrome_options.add_experimental_option("prefs", prefs)
        
        browser = webdriver.Chrome(executable_path="chromedriver.exe", options=chrome_options)
        browser.get(url)
        time.sleep(1)

        # To make it load more scroll to the bottom of the page (repeat if you want to)
        
        lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
        match = False
        while(match == False):
            lastCount = lenOfPage
            time.sleep(1)
            lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
            if lastCount == lenOfPage:
                match = True
                
        html_source = browser.page_source
        browser.quit()
        
        soup = BeautifulSoup(html_source, 'html.parser')
        check = soup.findAll('div', {'class' : 'sound__content'})
        if check == []:
            InfoOfOnePlaylist.append(Users[i][2])
            InfoOfOnePlaylist.append('None')
            InfoOfOnePlaylist.append('None')
            PlaylistOfAllUsers.append(InfoOfOnePlaylist)
        else:        
            for id in check:
                Title = id.find('a', {'class' : 'sc-link-primary soundTitle__title sc-link-dark sc-text-h4'})
                Tracks = id.findAll('span', {'class' : 'compactTrackListItem__trackTitle sc-text-primary sc-text-h4'})
                for Track in Tracks:
                    InfoOfOnePlaylist = []
                    InfoOfOnePlaylist.append(Users[i][2])
                    InfoOfOnePlaylist.append(Title.text)
                    InfoOfOnePlaylist.append(Track.text)
                    PlaylistOfAllUsers.append(InfoOfOnePlaylist)
    return PlaylistOfAllUsers

def writeUsersToCsv(List2D, filename):
    df = pd.DataFrame(List2D, columns = ['Url', 'Users Link', 'User Name'])
    df.to_csv(filename, index = True, sep = '\t')
    
def writeTracksToCsv(List2D, filename):
    df = pd.DataFrame(List2D, columns = ['User Name', 'Tracks Of One User'])
    df.to_csv(filename, index = True, sep = '\t')

def writePlaylistsToCsv(List2D, filename):
    df = pd.DataFrame(List2D, columns = ['User Name', 'Playlists Of One User', 'Tracks Of One Playlist'])
    df.to_csv(filename, index = True, sep = '\t')

# %%
#Lay du lieu tu cac link tong file top50_url.txt
filename = './url_entry/top50_url.txt'
urls = GetAllUrls(filename)

#lay users, tracks, playlists
users_Top50 = GetUsers(urls)
tracks_Top50 = GetTracks(users_Top50)
playlists_Top50 = GetPlaylists(users_Top50)

#Ghi xuong file csv
writeUsersToCsv(users_Top50, './Crawl_data/users.csv')
writeTracksToCsv(tracks_Top50, './Crawl_data/tracks.csv')
writePlaylistsToCsv(playlists_Top50, './Crawl_data/playlists.csv')

# %%
#lay ban du lieu tu top50_url.txt
Users = pd.read_csv('./Crawl_data/users.csv', sep='\t')
Users
# Out:
#      Unnamed: 0                                           Url  \
# 0             0         https://soundcloud.com/winnodamidside
# 1             1          https://soundcloud.com/t-h-i-n-h-h-o
# 2             2           https://soundcloud.com/youngcrizzal
# 3             3  https://soundcloud.com/hieutranmusicproducer
# 4             4         https://soundcloud.com/user-580335475
# ..          ...                                           ...
# 238         238          https://soundcloud.com/user-36782499
# 239         239  https://soundcloud.com/t-ng-nguy-n-603782925
# 240         240            https://soundcloud.com/hoangbaoduy
# 241         241    https://soundcloud.com/ti-n-d-ng-483096509
# 242         242       https://soundcloud.com/do-duy-525210277
#
#                  Users Link                   User Name
# 0           /winnodamidside           Hustlang Winno 🐉🐍
# 1            /t-h-i-n-h-h-o                     THINHHO
# 2             /youngcrizzal                          YC
# 3    /hieutranmusicproducer    Hieu Tran Music Producer
# 4           /user-580335475                   𝘂𝗺𝗰𝗻𝗴𝗱𝗰 🎶
# ..                      ...                         ...
# 238          /user-36782499  Phong Philipp ( Nick Phụ )
# 239  /t-ng-nguy-n-603782925                 Tùng Nguyễn
# 240            /hoangbaoduy              D&D Production
# 241    /ti-n-d-ng-483096509                   DJ Drop ✪
# 242       /do-duy-525210277                    Duy Pham
#
# [243 rows x 4 columns]

# %%
Tracks = pd.read_csv('./Crawl_data/tracks.csv', sep='\t')
Tracks
# Out:
#       Unnamed: 0          User Name  \
# 0              0  Hustlang Winno 🐉🐍
# 1              1  Hustlang Winno 🐉🐍
# 2              2  Hustlang Winno 🐉🐍
# 3              3  Hustlang Winno 🐉🐍
# 4              4  Hustlang Winno 🐉🐍
# ...          ...                ...
# 8517        8517           Duy Pham
# 8518        8518           Duy Pham
# 8519        8519           Duy Pham
# 8520        8520           Duy Pham
# 8521        8521           Duy Pham
#
#                                      Tracks Of One User
# 0                 \nTell Ur Mom II - Winno (ft Heily)\n
# 1                    \nLil Thang - pu ekvw Ft Hashone\n
# 2                    \nBốp 2 - Winno (Godthic dissin)\n
# 3                      \nBốp - Winno (Reply Zuyngusi)\n
# 4                       \nBounce. (remixbyMoTienSinh)\n
# ...                                                 ...
# 8517  \nBUSINESS X GUCCI GANG 2020 -HD Remix ( TƯƠI )\n
# 8518  \nHuong Ly - Yêu 1 Ngươi Tổn Thương 2021  - Qu...
# 8519   \nBINZ - BIG CITY BOY 2021 - Viez Remix (Tươi)\n
# 8520            \nSome One You Love - Kai Remix  FULL\n
# 8521       \n- Set Fire To The Rain fIX - Jet  Remixx\n
#
# [8522 rows x 3 columns]

# %%
Playlists = pd.read_csv('./Crawl_data/playlists.csv', sep='\t')
Playlists
# Out:
#       Unnamed: 0          User Name     Playlists Of One User  \
# 0              0  Hustlang Winno 🐉🐍                      None
# 1              1            THINHHO                      None
# 2              2                 YC  \nTren Lau Cao Remixes\n
# 3              3                 YC  \nTren Lau Cao Remixes\n
# 4              4                 YC  \nTren Lau Cao Remixes\n
# ...          ...                ...                       ...
# 1772        1772        Tùng Nguyễn           \nTùng ChiVas\n
# 1773        1773        Tùng Nguyễn           \nTùng ChiVas\n
# 1774        1774     D&D Production                      None
# 1775        1775          DJ Drop ✪                      None
# 1776        1776           Duy Pham                      None
#
#                                  Tracks Of One Playlist
# 0                                                  None
# 1                                                  None
# 2     \n    Rhymastic - Trên Lầu Cao ( Zan x TeaA re...
# 3      \n    Rhymastic - Trên Lầu Cao (Alden Remix)\n
# 4                                  \n    TRENLAUCAO\n
# ...                                                 ...
# 1772  \n    Mixset House Love ( Lak Chill ) Vol 3 --...
# 1773  \n    Mixset House Love Vội Vàng ( Lak Chill )...
# 1774                                               None
# 1775                                               None
# 1776                                               None
#
# [1777 rows x 4 columns]
